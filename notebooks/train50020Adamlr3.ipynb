# %% [markdown]
# # Training U-Net model
# ## 500 Epochs, 0.2 Dropout, Adam Optimizer, Learning Rate 1e-3

# %%
import sys
sys.path.append("..")
import os, re, glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from src import data,unet
# Out:
# Using TensorFlow backend.

# %%
from keras import utils
train_dir = "/home/ubuntu/trainingdata/TrainingSet"
weight_file = 'saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5'
save_imgs_dir = 'images/train50020DrpAdam3'

images = []
inner_masks = []
outer_masks = []

patient_directories = sorted(glob.glob(os.path.join(train_dir, "patient*")))

for patient_dir in patient_directories:
    imgdata = data.ImageData(patient_dir)
    images += imgdata.labeled_images
    inner_masks += imgdata.endo_masks
    outer_masks += imgdata.epi_masks

images = np.asarray(images)[:,:,:,None].astype('float64')
i_masks = np.asarray(inner_masks)
o_masks = np.asarray(outer_masks)

dims = i_masks.shape
classes = len(set(i_masks[0].flatten()))
new_shape = dims + (classes,)
i_masks = utils.to_categorical(i_masks).reshape(new_shape)
o_masks = utils.to_categorical(o_masks).reshape(new_shape)

def normalize(x, epsilon=1e-7, axis=(1,2)):
    x -= np.mean(x, axis=axis, keepdims=True)
    x /= np.std(x, axis=axis, keepdims=True) + epsilon
    
normalize(images,axis=(1,2))

print("There are %d total training images." % len(images))
print("There are %d total inner masks." % len(inner_masks))
print("There are %d total outer masks." % len(outer_masks))
# Out:
# There are 243 total training images.
# There are 243 total inner masks.
# There are 243 total outer masks.

# %%
height,width,_ = images[0].shape
dropout = 0.2
unet_conv = unet.UNet()

model = unet_conv.get_unet(height=height, width=width, channels=1,features=32,steps=3,dropout=dropout,padding='same')
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 216, 256, 1)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 216, 256, 32)  320         input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 216, 256, 32)  0           conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 216, 256, 32)  0           activation_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 216, 256, 32)  9248        dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 216, 256, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 216, 256, 32)  0           activation_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 108, 128, 32)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 108, 128, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 108, 128, 64)  0           conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 108, 128, 64)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 108, 128, 64)  36928       dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 108, 128, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 108, 128, 64)  0           activation_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 54, 64, 64)    0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 54, 64, 128)   73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 54, 64, 128)   0           conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 54, 64, 128)   0           activation_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 54, 64, 128)   147584      dropout_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 54, 64, 128)   0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 54, 64, 128)   0           activation_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 27, 32, 128)   0           dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 27, 32, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 27, 32, 256)   0           conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 27, 32, 256)   0           activation_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 27, 32, 256)   590080      dropout_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 27, 32, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 27, 32, 256)   0           activation_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 27, 32, 256)   590080      dropout_8[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 27, 32, 256)   0           conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 27, 32, 256)   0           activation_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 27, 32, 256)   590080      dropout_9[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 27, 32, 256)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 27, 32, 256)   0           activation_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTransp (None, 54, 64, 128)   131200      dropout_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 54, 64, 256)   0           conv2d_transpose_1[0][0]
#                                                                    conv2d_transpose_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 54, 64, 128)   295040      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 54, 64, 128)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, 54, 64, 128)   0           activation_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 54, 64, 128)   147584      dropout_11[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 54, 64, 128)   0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 54, 64, 128)   0           activation_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTransp (None, 108, 128, 64)  32832       dropout_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 108, 128, 128) 0           conv2d_transpose_2[0][0]
#                                                                    conv2d_transpose_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 108, 128, 64)  73792       concatenate_2[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 108, 128, 64)  0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 108, 128, 64)  0           activation_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 108, 128, 64)  36928       dropout_13[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 108, 128, 64)  0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 108, 128, 64)  0           activation_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTransp (None, 216, 256, 32)  8224        dropout_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 216, 256, 64)  0           conv2d_transpose_3[0][0]
#                                                                    conv2d_transpose_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 216, 256, 32)  18464       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 216, 256, 32)  0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 216, 256, 32)  0           activation_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 216, 256, 32)  9248        dropout_15[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 216, 256, 32)  0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 216, 256, 32)  0           activation_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 216, 256, 2)   66          dropout_16[0][0]
# ____________________________________________________________________________________________________
# lambda_1 (Lambda)                (None, 216, 256, 2)   0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 216, 256, 2)   0           lambda_1[0][0]
# ====================================================================================================
# Total params: 3,105,218
# Trainable params: 3,105,218
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from keras.optimizers import Adam, SGD
from keras import backend as K

def dice_coef(y_true, y_pred):
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    intersection = K.sum(flat_y_true * flat_y_pred)
    return (2. * intersection + 1.) / (K.sum(flat_y_true) + K.sum(flat_y_pred) + 1.)

def dice_coef_np(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection + 1.) / (np.sum(y_true) + np.sum(y_pred) + 1.)


def pixelwise_crossentropy(y_true, y_pred, weights=[0.5,0.5], epsilon=1e-8):
    ndim = K.ndim(y_pred)
    ncategory = K.int_shape(y_pred)[-1]
    # scale predictions so class probabilities of each pixel sum to 1
    y_pred /= K.sum(y_pred, axis=(ndim-1), keepdims=True)
    y_pred = K.clip(y_pred, epsilon, 1-epsilon)
    w = K.constant(weights) * (ncategory / sum(weights))
    # first, average over all axis except classes
    cross_entropies = -K.mean(y_true * K.log(y_pred), axis=tuple(range(ndim-1)))
    return K.sum(w * cross_entropies)


def show_plots(history):    
    plt.plot(history.history['dice_coef'])
    plt.plot(history.history['val_dice_coef'])
    plt.title('model dice')
    plt.ylabel('dice')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    plt.savefig(os.path.join(save_imgs_dir,"acc-loss-plot.png"))
model.compile(optimizer=Adam(lr=1e-3),loss=[pixelwise_crossentropy],metrics=[dice_coef])

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

from math import ceil

seed = 78

validation_split=0.2

epochs = 500
batch_size = 32


split_index = int((1 - validation_split) * len(images))

train_steps = ceil(split_index / batch_size)
val_steps = ceil((len(images)-split_index )/batch_size)

train_images = images[:split_index]
train_inner_masks = i_masks[:split_index]

validation_images = images[split_index:]
validation_inner_masks = i_masks[split_index:]


data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range=0.1,
                     zoom_range=0.05,
                     fill_mode='nearest')

train_images_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**data_gen_args)


#seed = 1
#height,width,channels = train_images[0].shape
#print(train_images[0].shape)
#print(train_inner_masks[0].shape)
train_images_datagen.fit(train_images,augment=True,seed=seed)
train_masks_datagen.fit(train_inner_masks,augment=True,seed=seed)

train_images_generator = train_images_datagen.flow(train_images, y=None, seed=seed)
train_masks_generator = train_images_datagen.flow(train_inner_masks, y=None, seed=seed)


train_generator = zip(train_images_generator, train_masks_generator)
# Out:
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.8-py3.5.egg/keras/preprocessing/image.py:653: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (194, 216, 256, 2) (2 channels).
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.8-py3.5.egg/keras/preprocessing/image.py:787: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (194, 216, 256, 2) (2 channels).

# %%
checkpointer = ModelCheckpoint(filepath=weight_file, verbose=1, save_best_only=True)

hist = model.fit_generator(train_generator,steps_per_epoch=train_steps,epochs=epochs,verbose=1,callbacks=[checkpointer],
                   validation_data=(validation_images,validation_inner_masks),validation_steps=val_steps)
# Out:
# Epoch 1/500
# 6/7 [========================>.....] - ETA: 3s - loss: 0.6742 - dice_coef: 0.5980Epoch 00000: val_loss improved from inf to 0.48068, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 22s - loss: 0.6123 - dice_coef: 0.6302 - val_loss: 0.4807 - val_dice_coef: 0.6229
# Epoch 2/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.2498 - dice_coef: 0.8593Epoch 00001: val_loss improved from 0.48068 to 0.28448, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.2463 - dice_coef: 0.8605 - val_loss: 0.2845 - val_dice_coef: 0.7696
# Epoch 3/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.2002 - dice_coef: 0.8910Epoch 00002: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.2124 - dice_coef: 0.8872 - val_loss: 0.3510 - val_dice_coef: 0.7139
# Epoch 4/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.2011 - dice_coef: 0.8828Epoch 00003: val_loss improved from 0.28448 to 0.27656, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.2014 - dice_coef: 0.8803 - val_loss: 0.2766 - val_dice_coef: 0.7737
# Epoch 5/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1762 - dice_coef: 0.9001Epoch 00004: val_loss improved from 0.27656 to 0.18854, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1711 - dice_coef: 0.9015 - val_loss: 0.1885 - val_dice_coef: 0.8527
# Epoch 6/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1619 - dice_coef: 0.9082Epoch 00005: val_loss improved from 0.18854 to 0.15589, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1547 - dice_coef: 0.9119 - val_loss: 0.1559 - val_dice_coef: 0.8845
# Epoch 7/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1554 - dice_coef: 0.9117Epoch 00006: val_loss improved from 0.15589 to 0.15386, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1618 - dice_coef: 0.9118 - val_loss: 0.1539 - val_dice_coef: 0.8838
# Epoch 8/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1471 - dice_coef: 0.9136Epoch 00007: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1488 - dice_coef: 0.9143 - val_loss: 0.1640 - val_dice_coef: 0.8728
# Epoch 9/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1400 - dice_coef: 0.9169Epoch 00008: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1417 - dice_coef: 0.9155 - val_loss: 0.1696 - val_dice_coef: 0.8693
# Epoch 10/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1347 - dice_coef: 0.9187Epoch 00009: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1451 - dice_coef: 0.9177 - val_loss: 0.1669 - val_dice_coef: 0.8684
# Epoch 11/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1378 - dice_coef: 0.9140Epoch 00010: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1384 - dice_coef: 0.9145 - val_loss: 0.1540 - val_dice_coef: 0.8807
# Epoch 12/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1306 - dice_coef: 0.9212Epoch 00011: val_loss improved from 0.15386 to 0.13176, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1284 - dice_coef: 0.9223 - val_loss: 0.1318 - val_dice_coef: 0.9029
# Epoch 13/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1303 - dice_coef: 0.9234Epoch 00012: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1316 - dice_coef: 0.9202 - val_loss: 0.1364 - val_dice_coef: 0.8974
# Epoch 14/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1333 - dice_coef: 0.9194Epoch 00013: val_loss improved from 0.13176 to 0.12409, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1317 - dice_coef: 0.9224 - val_loss: 0.1241 - val_dice_coef: 0.9089
# Epoch 15/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1259 - dice_coef: 0.9256Epoch 00014: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1246 - dice_coef: 0.9267 - val_loss: 0.1586 - val_dice_coef: 0.8741
# Epoch 16/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1232 - dice_coef: 0.9239Epoch 00015: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1192 - dice_coef: 0.9256 - val_loss: 0.1445 - val_dice_coef: 0.8871
# Epoch 17/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1181 - dice_coef: 0.9280Epoch 00016: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1206 - dice_coef: 0.9250 - val_loss: 0.1311 - val_dice_coef: 0.8997
# Epoch 18/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1179 - dice_coef: 0.9320Epoch 00017: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1262 - dice_coef: 0.9272 - val_loss: 0.2286 - val_dice_coef: 0.8146
# Epoch 19/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1330 - dice_coef: 0.9168Epoch 00018: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1325 - dice_coef: 0.9150 - val_loss: 0.1725 - val_dice_coef: 0.8639
# Epoch 20/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1241 - dice_coef: 0.9247Epoch 00019: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1221 - dice_coef: 0.9253 - val_loss: 0.1638 - val_dice_coef: 0.8699
# Epoch 21/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1220 - dice_coef: 0.9268Epoch 00020: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1253 - dice_coef: 0.9236 - val_loss: 0.1329 - val_dice_coef: 0.8979
# Epoch 22/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1139 - dice_coef: 0.9295Epoch 00021: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1146 - dice_coef: 0.9300 - val_loss: 0.1312 - val_dice_coef: 0.8997
# Epoch 23/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1132 - dice_coef: 0.9304Epoch 00022: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1111 - dice_coef: 0.9311 - val_loss: 0.1444 - val_dice_coef: 0.8877
# Epoch 24/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1159 - dice_coef: 0.9299Epoch 00023: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1147 - dice_coef: 0.9293 - val_loss: 0.1362 - val_dice_coef: 0.8949
# Epoch 25/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1128 - dice_coef: 0.9307Epoch 00024: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1136 - dice_coef: 0.9298 - val_loss: 0.1541 - val_dice_coef: 0.8804
# Epoch 26/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1095 - dice_coef: 0.9337Epoch 00025: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1122 - dice_coef: 0.9304 - val_loss: 0.1485 - val_dice_coef: 0.8835
# Epoch 27/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1151 - dice_coef: 0.9275Epoch 00026: val_loss improved from 0.12409 to 0.12383, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1129 - dice_coef: 0.9298 - val_loss: 0.1238 - val_dice_coef: 0.9074
# Epoch 28/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1154 - dice_coef: 0.9305Epoch 00027: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1061 - dice_coef: 0.9359 - val_loss: 0.1312 - val_dice_coef: 0.8998
# Epoch 29/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1076 - dice_coef: 0.9332Epoch 00028: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1062 - dice_coef: 0.9327 - val_loss: 0.1334 - val_dice_coef: 0.8971
# Epoch 30/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1124 - dice_coef: 0.9324Epoch 00029: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1155 - dice_coef: 0.9293 - val_loss: 0.1252 - val_dice_coef: 0.9039
# Epoch 31/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1069 - dice_coef: 0.9337Epoch 00030: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1094 - dice_coef: 0.9315 - val_loss: 0.1328 - val_dice_coef: 0.8973
# Epoch 32/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1070 - dice_coef: 0.9333Epoch 00031: val_loss improved from 0.12383 to 0.11033, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1019 - dice_coef: 0.9351 - val_loss: 0.1103 - val_dice_coef: 0.9237
# Epoch 33/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1121 - dice_coef: 0.9336Epoch 00032: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1085 - dice_coef: 0.9353 - val_loss: 0.1354 - val_dice_coef: 0.8947
# Epoch 34/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1041 - dice_coef: 0.9346Epoch 00033: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1028 - dice_coef: 0.9343 - val_loss: 0.1219 - val_dice_coef: 0.9075
# Epoch 35/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1045 - dice_coef: 0.9361Epoch 00034: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1088 - dice_coef: 0.9342 - val_loss: 0.1740 - val_dice_coef: 0.8615
# Epoch 36/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1113 - dice_coef: 0.9294Epoch 00035: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1111 - dice_coef: 0.9285 - val_loss: 0.1789 - val_dice_coef: 0.8575
# Epoch 37/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1090 - dice_coef: 0.9312Epoch 00036: val_loss improved from 0.11033 to 0.10824, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1080 - dice_coef: 0.9313 - val_loss: 0.1082 - val_dice_coef: 0.9213
# Epoch 38/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1052 - dice_coef: 0.9371Epoch 00037: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1058 - dice_coef: 0.9369 - val_loss: 0.1429 - val_dice_coef: 0.8882
# Epoch 39/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1019 - dice_coef: 0.9345Epoch 00038: val_loss improved from 0.10824 to 0.10612, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0993 - dice_coef: 0.9351 - val_loss: 0.1061 - val_dice_coef: 0.9282
# Epoch 40/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1013 - dice_coef: 0.9397Epoch 00039: val_loss improved from 0.10612 to 0.10335, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1009 - dice_coef: 0.9396 - val_loss: 0.1033 - val_dice_coef: 0.9256
# Epoch 41/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1079 - dice_coef: 0.9345Epoch 00040: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1021 - dice_coef: 0.9385 - val_loss: 0.1144 - val_dice_coef: 0.9145
# Epoch 42/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1014 - dice_coef: 0.9357Epoch 00041: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0990 - dice_coef: 0.9379 - val_loss: 0.1247 - val_dice_coef: 0.9043
# Epoch 43/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0986 - dice_coef: 0.9372Epoch 00042: val_loss improved from 0.10335 to 0.10013, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0958 - dice_coef: 0.9388 - val_loss: 0.1001 - val_dice_coef: 0.9288
# Epoch 44/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1002 - dice_coef: 0.9392Epoch 00043: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0977 - dice_coef: 0.9407 - val_loss: 0.1591 - val_dice_coef: 0.8781
# Epoch 45/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1056 - dice_coef: 0.9349Epoch 00044: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1083 - dice_coef: 0.9315 - val_loss: 0.1473 - val_dice_coef: 0.8827
# Epoch 46/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0939 - dice_coef: 0.9399Epoch 00045: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1029 - dice_coef: 0.9411 - val_loss: 0.1548 - val_dice_coef: 0.8836
# Epoch 47/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1007 - dice_coef: 0.9373Epoch 00046: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1014 - dice_coef: 0.9363 - val_loss: 0.1386 - val_dice_coef: 0.8922
# Epoch 48/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1009 - dice_coef: 0.9391Epoch 00047: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1049 - dice_coef: 0.9385 - val_loss: 0.1608 - val_dice_coef: 0.8741
# Epoch 49/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1043 - dice_coef: 0.9336Epoch 00048: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1041 - dice_coef: 0.9330 - val_loss: 0.1351 - val_dice_coef: 0.8973
# Epoch 50/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0942 - dice_coef: 0.9410Epoch 00049: val_loss improved from 0.10013 to 0.10010, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0931 - dice_coef: 0.9411 - val_loss: 0.1001 - val_dice_coef: 0.9346
# Epoch 51/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1024 - dice_coef: 0.9399Epoch 00050: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1040 - dice_coef: 0.9385 - val_loss: 0.1254 - val_dice_coef: 0.9019
# Epoch 52/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0924 - dice_coef: 0.9416Epoch 00051: val_loss improved from 0.10010 to 0.09815, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0978 - dice_coef: 0.9390 - val_loss: 0.0982 - val_dice_coef: 0.9320
# Epoch 53/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1166 - dice_coef: 0.9296Epoch 00052: val_loss improved from 0.09815 to 0.09387, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1085 - dice_coef: 0.9345 - val_loss: 0.0939 - val_dice_coef: 0.9343
# Epoch 54/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0975 - dice_coef: 0.9385Epoch 00053: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0932 - dice_coef: 0.9424 - val_loss: 0.1066 - val_dice_coef: 0.9224
# Epoch 55/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1004 - dice_coef: 0.9357Epoch 00054: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1032 - dice_coef: 0.9342 - val_loss: 0.1117 - val_dice_coef: 0.9145
# Epoch 56/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0947 - dice_coef: 0.9395Epoch 00055: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0981 - dice_coef: 0.9377 - val_loss: 0.1142 - val_dice_coef: 0.9145
# Epoch 57/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0924 - dice_coef: 0.9412Epoch 00056: val_loss improved from 0.09387 to 0.09201, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0897 - dice_coef: 0.9421 - val_loss: 0.0920 - val_dice_coef: 0.9390
# Epoch 58/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0977 - dice_coef: 0.9398Epoch 00057: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0935 - dice_coef: 0.9426 - val_loss: 0.1064 - val_dice_coef: 0.9438
# Epoch 59/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0927 - dice_coef: 0.9430Epoch 00058: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0886 - dice_coef: 0.9458 - val_loss: 0.0999 - val_dice_coef: 0.9255
# Epoch 60/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0876 - dice_coef: 0.9446Epoch 00059: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0850 - dice_coef: 0.9460 - val_loss: 0.0929 - val_dice_coef: 0.9306
# Epoch 61/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0813 - dice_coef: 0.9487Epoch 00060: val_loss improved from 0.09201 to 0.08337, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0822 - dice_coef: 0.9474 - val_loss: 0.0834 - val_dice_coef: 0.9393
# Epoch 62/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0804 - dice_coef: 0.9505Epoch 00061: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0851 - dice_coef: 0.9488 - val_loss: 0.0922 - val_dice_coef: 0.9293
# Epoch 63/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0818 - dice_coef: 0.9510Epoch 00062: val_loss improved from 0.08337 to 0.08156, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0790 - dice_coef: 0.9522 - val_loss: 0.0816 - val_dice_coef: 0.9387
# Epoch 64/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0762 - dice_coef: 0.9559Epoch 00063: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0740 - dice_coef: 0.9576 - val_loss: 0.0826 - val_dice_coef: 0.9450
# Epoch 65/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0913 - dice_coef: 0.9461Epoch 00064: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0901 - dice_coef: 0.9465 - val_loss: 0.1081 - val_dice_coef: 0.9151
# Epoch 66/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0757 - dice_coef: 0.9532Epoch 00065: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0732 - dice_coef: 0.9544 - val_loss: 0.1474 - val_dice_coef: 0.9577
# Epoch 67/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1021 - dice_coef: 0.9482Epoch 00066: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1019 - dice_coef: 0.9462 - val_loss: 0.1609 - val_dice_coef: 0.8728
# Epoch 68/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0892 - dice_coef: 0.9432Epoch 00067: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0866 - dice_coef: 0.9443 - val_loss: 0.0840 - val_dice_coef: 0.9405
# Epoch 69/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0754 - dice_coef: 0.9556Epoch 00068: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0734 - dice_coef: 0.9559 - val_loss: 0.0887 - val_dice_coef: 0.9325
# Epoch 70/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0763 - dice_coef: 0.9569Epoch 00069: val_loss improved from 0.08156 to 0.07285, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0758 - dice_coef: 0.9573 - val_loss: 0.0728 - val_dice_coef: 0.9538
# Epoch 71/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0730 - dice_coef: 0.9576Epoch 00070: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0781 - dice_coef: 0.9534 - val_loss: 0.0895 - val_dice_coef: 0.9362
# Epoch 72/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1159 - dice_coef: 0.9329Epoch 00071: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1230 - dice_coef: 0.9314 - val_loss: 0.1836 - val_dice_coef: 0.8613
# Epoch 73/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1154 - dice_coef: 0.9285Epoch 00072: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1122 - dice_coef: 0.9291 - val_loss: 0.1267 - val_dice_coef: 0.9015
# Epoch 74/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0982 - dice_coef: 0.9396Epoch 00073: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0938 - dice_coef: 0.9418 - val_loss: 0.1231 - val_dice_coef: 0.9024
# Epoch 75/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0947 - dice_coef: 0.9440Epoch 00074: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0918 - dice_coef: 0.9441 - val_loss: 0.1028 - val_dice_coef: 0.9243
# Epoch 76/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0840 - dice_coef: 0.9504Epoch 00075: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0800 - dice_coef: 0.9514 - val_loss: 0.0958 - val_dice_coef: 0.9286
# Epoch 77/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0776 - dice_coef: 0.9542Epoch 00076: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0806 - dice_coef: 0.9526 - val_loss: 0.0890 - val_dice_coef: 0.9536
# Epoch 78/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0751 - dice_coef: 0.9554Epoch 00077: val_loss improved from 0.07285 to 0.07147, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0716 - dice_coef: 0.9571 - val_loss: 0.0715 - val_dice_coef: 0.9531
# Epoch 79/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0683 - dice_coef: 0.9602Epoch 00078: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0662 - dice_coef: 0.9618 - val_loss: 0.0917 - val_dice_coef: 0.9551
# Epoch 80/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0682 - dice_coef: 0.9604Epoch 00079: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0672 - dice_coef: 0.9609 - val_loss: 0.0870 - val_dice_coef: 0.9384
# Epoch 81/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0638 - dice_coef: 0.9621Epoch 00080: val_loss improved from 0.07147 to 0.06573, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0629 - dice_coef: 0.9631 - val_loss: 0.0657 - val_dice_coef: 0.9589
# Epoch 82/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0621 - dice_coef: 0.9638Epoch 00081: val_loss improved from 0.06573 to 0.05684, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0597 - dice_coef: 0.9647 - val_loss: 0.0568 - val_dice_coef: 0.9639
# Epoch 83/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0667 - dice_coef: 0.9613Epoch 00082: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0650 - dice_coef: 0.9616 - val_loss: 0.0671 - val_dice_coef: 0.9635
# Epoch 84/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0619 - dice_coef: 0.9675Epoch 00083: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0593 - dice_coef: 0.9682 - val_loss: 0.0580 - val_dice_coef: 0.9624
# Epoch 85/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0565 - dice_coef: 0.9668Epoch 00084: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0543 - dice_coef: 0.9686 - val_loss: 0.0576 - val_dice_coef: 0.9615
# Epoch 86/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0562 - dice_coef: 0.9686Epoch 00085: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0573 - dice_coef: 0.9693 - val_loss: 0.0700 - val_dice_coef: 0.9528
# Epoch 87/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0551 - dice_coef: 0.9660Epoch 00086: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0543 - dice_coef: 0.9667 - val_loss: 0.0581 - val_dice_coef: 0.9629
# Epoch 88/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0517 - dice_coef: 0.9714Epoch 00087: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0501 - dice_coef: 0.9719 - val_loss: 0.0813 - val_dice_coef: 0.9486
# Epoch 89/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0597 - dice_coef: 0.9662Epoch 00088: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0616 - dice_coef: 0.9647 - val_loss: 0.0780 - val_dice_coef: 0.9525
# Epoch 90/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0572 - dice_coef: 0.9653Epoch 00089: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0581 - dice_coef: 0.9651 - val_loss: 0.0876 - val_dice_coef: 0.9662
# Epoch 91/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0848 - dice_coef: 0.9522Epoch 00090: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0844 - dice_coef: 0.9542 - val_loss: 0.0659 - val_dice_coef: 0.9683
# Epoch 92/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0596 - dice_coef: 0.9645Epoch 00091: val_loss improved from 0.05684 to 0.05565, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0581 - dice_coef: 0.9646 - val_loss: 0.0557 - val_dice_coef: 0.9646
# Epoch 93/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0536 - dice_coef: 0.9701Epoch 00092: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0548 - dice_coef: 0.9684 - val_loss: 0.0567 - val_dice_coef: 0.9646
# Epoch 94/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0558 - dice_coef: 0.9698Epoch 00093: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0564 - dice_coef: 0.9695 - val_loss: 0.0636 - val_dice_coef: 0.9563
# Epoch 95/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0535 - dice_coef: 0.9670Epoch 00094: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0526 - dice_coef: 0.9670 - val_loss: 0.0837 - val_dice_coef: 0.9615
# Epoch 96/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0538 - dice_coef: 0.9705Epoch 00095: val_loss improved from 0.05565 to 0.04761, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0535 - dice_coef: 0.9709 - val_loss: 0.0476 - val_dice_coef: 0.9707
# Epoch 97/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0469 - dice_coef: 0.9714Epoch 00096: val_loss improved from 0.04761 to 0.04352, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0448 - dice_coef: 0.9728 - val_loss: 0.0435 - val_dice_coef: 0.9747
# Epoch 98/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0462 - dice_coef: 0.9742Epoch 00097: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0472 - dice_coef: 0.9733 - val_loss: 0.0516 - val_dice_coef: 0.9696
# Epoch 99/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0525 - dice_coef: 0.9710Epoch 00098: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0556 - dice_coef: 0.9691 - val_loss: 0.0968 - val_dice_coef: 0.9512
# Epoch 100/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0555 - dice_coef: 0.9656Epoch 00099: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0571 - dice_coef: 0.9651 - val_loss: 0.0618 - val_dice_coef: 0.9597
# Epoch 101/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0470 - dice_coef: 0.9721Epoch 00100: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0476 - dice_coef: 0.9718 - val_loss: 0.0659 - val_dice_coef: 0.9577
# Epoch 102/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0515 - dice_coef: 0.9728Epoch 00101: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0501 - dice_coef: 0.9727 - val_loss: 0.0509 - val_dice_coef: 0.9697
# Epoch 103/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0462 - dice_coef: 0.9729Epoch 00102: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0447 - dice_coef: 0.9737 - val_loss: 0.0502 - val_dice_coef: 0.9703
# Epoch 104/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0430 - dice_coef: 0.9752Epoch 00103: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0415 - dice_coef: 0.9759 - val_loss: 0.0553 - val_dice_coef: 0.9657
# Epoch 105/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0400 - dice_coef: 0.9770Epoch 00104: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0381 - dice_coef: 0.9779 - val_loss: 0.0499 - val_dice_coef: 0.9691
# Epoch 106/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0444 - dice_coef: 0.9757Epoch 00105: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0415 - dice_coef: 0.9775 - val_loss: 0.0485 - val_dice_coef: 0.9722
# Epoch 107/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0406 - dice_coef: 0.9759Epoch 00106: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0455 - dice_coef: 0.9744 - val_loss: 0.1100 - val_dice_coef: 0.9431
# Epoch 108/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0696 - dice_coef: 0.9618Epoch 00107: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0675 - dice_coef: 0.9617 - val_loss: 0.0686 - val_dice_coef: 0.9488
# Epoch 109/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0518 - dice_coef: 0.9668Epoch 00108: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0498 - dice_coef: 0.9680 - val_loss: 0.0527 - val_dice_coef: 0.9773
# Epoch 110/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0533 - dice_coef: 0.9717Epoch 00109: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0530 - dice_coef: 0.9717 - val_loss: 0.0504 - val_dice_coef: 0.9708
# Epoch 111/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0525 - dice_coef: 0.9690Epoch 00110: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0495 - dice_coef: 0.9708 - val_loss: 0.0484 - val_dice_coef: 0.9736
# Epoch 112/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0434 - dice_coef: 0.9755Epoch 00111: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0419 - dice_coef: 0.9760 - val_loss: 0.0590 - val_dice_coef: 0.9669
# Epoch 113/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0436 - dice_coef: 0.9788Epoch 00112: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0425 - dice_coef: 0.9785 - val_loss: 0.0493 - val_dice_coef: 0.9708
# Epoch 114/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0452 - dice_coef: 0.9720Epoch 00113: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0472 - dice_coef: 0.9710 - val_loss: 0.0552 - val_dice_coef: 0.9670
# Epoch 115/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0547 - dice_coef: 0.9718Epoch 00114: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0551 - dice_coef: 0.9700 - val_loss: 0.0604 - val_dice_coef: 0.9569
# Epoch 116/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0453 - dice_coef: 0.9724Epoch 00115: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0480 - dice_coef: 0.9713 - val_loss: 0.0464 - val_dice_coef: 0.9758
# Epoch 117/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0462 - dice_coef: 0.9723Epoch 00116: val_loss improved from 0.04352 to 0.04142, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0456 - dice_coef: 0.9723 - val_loss: 0.0414 - val_dice_coef: 0.9734
# Epoch 118/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0413 - dice_coef: 0.9771Epoch 00117: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0396 - dice_coef: 0.9778 - val_loss: 0.0626 - val_dice_coef: 0.9749
# Epoch 119/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0422 - dice_coef: 0.9775Epoch 00118: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0407 - dice_coef: 0.9775 - val_loss: 0.0459 - val_dice_coef: 0.9711
# Epoch 120/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0348 - dice_coef: 0.9792Epoch 00119: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0362 - dice_coef: 0.9791 - val_loss: 0.0523 - val_dice_coef: 0.9719
# Epoch 121/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0409 - dice_coef: 0.9775Epoch 00120: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0417 - dice_coef: 0.9768 - val_loss: 0.0433 - val_dice_coef: 0.9709
# Epoch 122/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0342 - dice_coef: 0.9793Epoch 00121: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0341 - dice_coef: 0.9797 - val_loss: 0.0503 - val_dice_coef: 0.9685
# Epoch 123/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0360 - dice_coef: 0.9787Epoch 00122: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0343 - dice_coef: 0.9797 - val_loss: 0.0449 - val_dice_coef: 0.9761
# Epoch 124/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0327 - dice_coef: 0.9812Epoch 00123: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0319 - dice_coef: 0.9817 - val_loss: 0.0453 - val_dice_coef: 0.9733
# Epoch 125/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0319 - dice_coef: 0.9821Epoch 00124: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0311 - dice_coef: 0.9823 - val_loss: 0.0639 - val_dice_coef: 0.9665
# Epoch 126/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0303 - dice_coef: 0.9828Epoch 00125: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0316 - dice_coef: 0.9820 - val_loss: 0.0683 - val_dice_coef: 0.9631
# Epoch 127/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0459 - dice_coef: 0.9756Epoch 00126: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0434 - dice_coef: 0.9762 - val_loss: 0.0606 - val_dice_coef: 0.9583
# Epoch 128/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0405 - dice_coef: 0.9771Epoch 00127: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0397 - dice_coef: 0.9774 - val_loss: 0.0527 - val_dice_coef: 0.9685
# Epoch 129/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0343 - dice_coef: 0.9792Epoch 00128: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0336 - dice_coef: 0.9798 - val_loss: 0.0514 - val_dice_coef: 0.9719
# Epoch 130/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0350 - dice_coef: 0.9803Epoch 00129: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0336 - dice_coef: 0.9805 - val_loss: 0.0426 - val_dice_coef: 0.9732
# Epoch 131/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0316 - dice_coef: 0.9811Epoch 00130: val_loss improved from 0.04142 to 0.03560, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0314 - dice_coef: 0.9811 - val_loss: 0.0356 - val_dice_coef: 0.9784
# Epoch 132/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0362 - dice_coef: 0.9800Epoch 00131: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0375 - dice_coef: 0.9794 - val_loss: 0.0372 - val_dice_coef: 0.9760
# Epoch 133/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0339 - dice_coef: 0.9809Epoch 00132: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0334 - dice_coef: 0.9811 - val_loss: 0.0453 - val_dice_coef: 0.9694
# Epoch 134/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0311 - dice_coef: 0.9820Epoch 00133: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0307 - dice_coef: 0.9820 - val_loss: 0.0441 - val_dice_coef: 0.9727
# Epoch 135/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0285 - dice_coef: 0.9838Epoch 00134: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0263 - dice_coef: 0.9848 - val_loss: 0.0474 - val_dice_coef: 0.9733
# Epoch 136/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0281 - dice_coef: 0.9839Epoch 00135: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0298 - dice_coef: 0.9832 - val_loss: 0.0400 - val_dice_coef: 0.9773
# Epoch 137/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0283 - dice_coef: 0.9828Epoch 00136: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0278 - dice_coef: 0.9830 - val_loss: 0.0451 - val_dice_coef: 0.9743
# Epoch 138/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0272 - dice_coef: 0.9845Epoch 00137: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0271 - dice_coef: 0.9842 - val_loss: 0.0446 - val_dice_coef: 0.9785
# Epoch 139/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0293 - dice_coef: 0.9837Epoch 00138: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0294 - dice_coef: 0.9833 - val_loss: 0.0459 - val_dice_coef: 0.9732
# Epoch 140/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0269 - dice_coef: 0.9846Epoch 00139: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0269 - dice_coef: 0.9848 - val_loss: 0.0434 - val_dice_coef: 0.9788
# Epoch 141/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0255 - dice_coef: 0.9851Epoch 00140: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0273 - dice_coef: 0.9843 - val_loss: 0.0429 - val_dice_coef: 0.9748
# Epoch 142/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0296 - dice_coef: 0.9826Epoch 00141: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0300 - dice_coef: 0.9830 - val_loss: 0.0405 - val_dice_coef: 0.9728
# Epoch 143/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0304 - dice_coef: 0.9810Epoch 00142: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0289 - dice_coef: 0.9818 - val_loss: 0.0375 - val_dice_coef: 0.9832
# Epoch 144/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0297 - dice_coef: 0.9856Epoch 00143: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0285 - dice_coef: 0.9856 - val_loss: 0.0398 - val_dice_coef: 0.9756
# Epoch 145/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0301 - dice_coef: 0.9815Epoch 00144: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0315 - dice_coef: 0.9813 - val_loss: 0.0373 - val_dice_coef: 0.9771
# Epoch 146/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0321 - dice_coef: 0.9805Epoch 00145: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0347 - dice_coef: 0.9795 - val_loss: 0.0415 - val_dice_coef: 0.9758
# Epoch 147/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0318 - dice_coef: 0.9818Epoch 00146: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0319 - dice_coef: 0.9815 - val_loss: 0.0403 - val_dice_coef: 0.9776
# Epoch 148/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0312 - dice_coef: 0.9831Epoch 00147: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0309 - dice_coef: 0.9826 - val_loss: 0.0460 - val_dice_coef: 0.9709
# Epoch 149/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0313 - dice_coef: 0.9822Epoch 00148: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0295 - dice_coef: 0.9830 - val_loss: 0.0434 - val_dice_coef: 0.9772
# Epoch 150/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0294 - dice_coef: 0.9833Epoch 00149: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0312 - dice_coef: 0.9824 - val_loss: 0.0410 - val_dice_coef: 0.9722
# Epoch 151/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0262 - dice_coef: 0.9840Epoch 00150: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0300 - dice_coef: 0.9828 - val_loss: 0.0440 - val_dice_coef: 0.9736
# Epoch 152/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0361 - dice_coef: 0.9798Epoch 00151: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0448 - dice_coef: 0.9761 - val_loss: 0.0503 - val_dice_coef: 0.9739
# Epoch 153/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0544 - dice_coef: 0.9661Epoch 00152: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0518 - dice_coef: 0.9675 - val_loss: 0.0486 - val_dice_coef: 0.9739
# Epoch 154/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0417 - dice_coef: 0.9772Epoch 00153: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0397 - dice_coef: 0.9777 - val_loss: 0.0372 - val_dice_coef: 0.9811
# Epoch 155/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0354 - dice_coef: 0.9803Epoch 00154: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0341 - dice_coef: 0.9811 - val_loss: 0.0390 - val_dice_coef: 0.9791
# Epoch 156/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0325 - dice_coef: 0.9819Epoch 00155: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0330 - dice_coef: 0.9815 - val_loss: 0.0430 - val_dice_coef: 0.9731
# Epoch 157/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0292 - dice_coef: 0.9824Epoch 00156: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0300 - dice_coef: 0.9816 - val_loss: 0.0625 - val_dice_coef: 0.9651
# Epoch 158/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0295 - dice_coef: 0.9842Epoch 00157: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0295 - dice_coef: 0.9842 - val_loss: 0.0746 - val_dice_coef: 0.9647
# Epoch 159/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0404 - dice_coef: 0.9796Epoch 00158: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0389 - dice_coef: 0.9796 - val_loss: 0.0457 - val_dice_coef: 0.9687
# Epoch 160/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0323 - dice_coef: 0.9805Epoch 00159: val_loss improved from 0.03560 to 0.03337, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0314 - dice_coef: 0.9811 - val_loss: 0.0334 - val_dice_coef: 0.9817
# Epoch 161/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0270 - dice_coef: 0.9842Epoch 00160: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0262 - dice_coef: 0.9844 - val_loss: 0.0383 - val_dice_coef: 0.9793
# Epoch 162/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0259 - dice_coef: 0.9847Epoch 00161: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0279 - dice_coef: 0.9834 - val_loss: 0.0461 - val_dice_coef: 0.9748
# Epoch 163/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0326 - dice_coef: 0.9827Epoch 00162: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0314 - dice_coef: 0.9829 - val_loss: 0.0466 - val_dice_coef: 0.9732
# Epoch 164/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0294 - dice_coef: 0.9823Epoch 00163: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0290 - dice_coef: 0.9827 - val_loss: 0.0334 - val_dice_coef: 0.9798
# Epoch 165/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0256 - dice_coef: 0.9846Epoch 00164: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0259 - dice_coef: 0.9845 - val_loss: 0.0350 - val_dice_coef: 0.9804
# Epoch 166/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0258 - dice_coef: 0.9861Epoch 00165: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0255 - dice_coef: 0.9858 - val_loss: 0.0409 - val_dice_coef: 0.9780
# Epoch 167/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0237 - dice_coef: 0.9862Epoch 00166: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0222 - dice_coef: 0.9869 - val_loss: 0.0397 - val_dice_coef: 0.9791
# Epoch 168/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0230 - dice_coef: 0.9868Epoch 00167: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0244 - dice_coef: 0.9862 - val_loss: 0.0500 - val_dice_coef: 0.9738
# Epoch 169/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0361 - dice_coef: 0.9816Epoch 00168: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0364 - dice_coef: 0.9809 - val_loss: 0.0487 - val_dice_coef: 0.9663
# Epoch 170/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0347 - dice_coef: 0.9788Epoch 00169: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0331 - dice_coef: 0.9796 - val_loss: 0.0361 - val_dice_coef: 0.9807
# Epoch 171/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0303 - dice_coef: 0.9834Epoch 00170: val_loss improved from 0.03337 to 0.03278, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0289 - dice_coef: 0.9839 - val_loss: 0.0328 - val_dice_coef: 0.9821
# Epoch 172/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0271 - dice_coef: 0.9837Epoch 00171: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0287 - dice_coef: 0.9823 - val_loss: 0.0346 - val_dice_coef: 0.9815
# Epoch 173/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0245 - dice_coef: 0.9860Epoch 00172: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0245 - dice_coef: 0.9857 - val_loss: 0.0417 - val_dice_coef: 0.9785
# Epoch 174/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0253 - dice_coef: 0.9861Epoch 00173: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0248 - dice_coef: 0.9860 - val_loss: 0.0462 - val_dice_coef: 0.9782
# Epoch 175/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0246 - dice_coef: 0.9861Epoch 00174: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0262 - dice_coef: 0.9852 - val_loss: 0.0456 - val_dice_coef: 0.9739
# Epoch 176/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0307 - dice_coef: 0.9825Epoch 00175: val_loss improved from 0.03278 to 0.02994, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0291 - dice_coef: 0.9833 - val_loss: 0.0299 - val_dice_coef: 0.9842
# Epoch 177/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0273 - dice_coef: 0.9841Epoch 00176: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0264 - dice_coef: 0.9843 - val_loss: 0.0313 - val_dice_coef: 0.9817
# Epoch 178/500
# ...
# 7/7 [==============================] - 13s - loss: 0.0162 - dice_coef: 0.9910 - val_loss: 0.0313 - val_dice_coef: 0.9840
# Epoch 439/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0158 - dice_coef: 0.9904Epoch 00438: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0151 - dice_coef: 0.9908 - val_loss: 0.0247 - val_dice_coef: 0.9869
# Epoch 440/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0155 - dice_coef: 0.9905Epoch 00439: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0152 - dice_coef: 0.9907 - val_loss: 0.0286 - val_dice_coef: 0.9845
# Epoch 441/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0159 - dice_coef: 0.9908Epoch 00440: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0166 - dice_coef: 0.9904 - val_loss: 0.0341 - val_dice_coef: 0.9810
# Epoch 442/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0156 - dice_coef: 0.9903Epoch 00441: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0161 - dice_coef: 0.9900 - val_loss: 0.0261 - val_dice_coef: 0.9864
# Epoch 443/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9907Epoch 00442: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0166 - dice_coef: 0.9904 - val_loss: 0.0332 - val_dice_coef: 0.9826
# Epoch 444/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0215 - dice_coef: 0.9872Epoch 00443: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0213 - dice_coef: 0.9878 - val_loss: 0.0239 - val_dice_coef: 0.9868
# Epoch 445/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0236 - dice_coef: 0.9855Epoch 00444: val_loss improved from 0.02359 to 0.02310, saving model to saved_models/endo_models/weights-500Epochs-20Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0231 - dice_coef: 0.9858 - val_loss: 0.0231 - val_dice_coef: 0.9870
# Epoch 446/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0196 - dice_coef: 0.9888Epoch 00445: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0191 - dice_coef: 0.9890 - val_loss: 0.0397 - val_dice_coef: 0.9797
# Epoch 447/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0190 - dice_coef: 0.9889Epoch 00446: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0196 - dice_coef: 0.9886 - val_loss: 0.0311 - val_dice_coef: 0.9832
# Epoch 448/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0181 - dice_coef: 0.9889Epoch 00447: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0183 - dice_coef: 0.9888 - val_loss: 0.0261 - val_dice_coef: 0.9850
# Epoch 449/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0165 - dice_coef: 0.9898Epoch 00448: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0158 - dice_coef: 0.9902 - val_loss: 0.0259 - val_dice_coef: 0.9858
# Epoch 450/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0161 - dice_coef: 0.9904Epoch 00449: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0157 - dice_coef: 0.9907 - val_loss: 0.0247 - val_dice_coef: 0.9868
# Epoch 451/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0159 - dice_coef: 0.9905Epoch 00450: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0163 - dice_coef: 0.9902 - val_loss: 0.0251 - val_dice_coef: 0.9862
# Epoch 452/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0157 - dice_coef: 0.9905Epoch 00451: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0153 - dice_coef: 0.9907 - val_loss: 0.0301 - val_dice_coef: 0.9840
# Epoch 453/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0150 - dice_coef: 0.9907Epoch 00452: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0147 - dice_coef: 0.9911 - val_loss: 0.0268 - val_dice_coef: 0.9867
# Epoch 454/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0149 - dice_coef: 0.9910Epoch 00453: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0144 - dice_coef: 0.9912 - val_loss: 0.0303 - val_dice_coef: 0.9848
# Epoch 455/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0150 - dice_coef: 0.9909Epoch 00454: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0163 - dice_coef: 0.9906 - val_loss: 0.0293 - val_dice_coef: 0.9854
# Epoch 456/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9905Epoch 00455: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0152 - dice_coef: 0.9906 - val_loss: 0.0273 - val_dice_coef: 0.9842
# Epoch 457/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0149 - dice_coef: 0.9904Epoch 00456: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0146 - dice_coef: 0.9906 - val_loss: 0.0254 - val_dice_coef: 0.9867
# Epoch 458/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9912Epoch 00457: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0154 - dice_coef: 0.9910 - val_loss: 0.0264 - val_dice_coef: 0.9868
# Epoch 459/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9910Epoch 00458: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0155 - dice_coef: 0.9906 - val_loss: 0.0242 - val_dice_coef: 0.9870
# Epoch 460/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0158 - dice_coef: 0.9907Epoch 00459: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0154 - dice_coef: 0.9908 - val_loss: 0.0283 - val_dice_coef: 0.9843
# Epoch 461/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0161 - dice_coef: 0.9902Epoch 00460: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0156 - dice_coef: 0.9907 - val_loss: 0.0258 - val_dice_coef: 0.9870
# Epoch 462/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0152 - dice_coef: 0.9908Epoch 00461: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0144 - dice_coef: 0.9912 - val_loss: 0.0297 - val_dice_coef: 0.9842
# Epoch 463/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0145 - dice_coef: 0.9911Epoch 00462: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0154 - dice_coef: 0.9906 - val_loss: 0.0244 - val_dice_coef: 0.9866
# Epoch 464/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0175 - dice_coef: 0.9896Epoch 00463: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0169 - dice_coef: 0.9898 - val_loss: 0.0564 - val_dice_coef: 0.9822
# Epoch 465/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0237 - dice_coef: 0.9871Epoch 00464: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0230 - dice_coef: 0.9871 - val_loss: 0.0531 - val_dice_coef: 0.9696
# Epoch 466/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0212 - dice_coef: 0.9873Epoch 00465: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0208 - dice_coef: 0.9877 - val_loss: 0.0360 - val_dice_coef: 0.9845
# Epoch 467/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0164 - dice_coef: 0.9903Epoch 00466: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0163 - dice_coef: 0.9903 - val_loss: 0.0341 - val_dice_coef: 0.9840
# Epoch 468/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0163 - dice_coef: 0.9903Epoch 00467: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0155 - dice_coef: 0.9906 - val_loss: 0.0326 - val_dice_coef: 0.9838
# Epoch 469/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0148 - dice_coef: 0.9908Epoch 00468: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0143 - dice_coef: 0.9911 - val_loss: 0.0291 - val_dice_coef: 0.9861
# Epoch 470/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9912Epoch 00469: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0150 - dice_coef: 0.9910 - val_loss: 0.0278 - val_dice_coef: 0.9868
# Epoch 471/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9910Epoch 00470: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0150 - dice_coef: 0.9910 - val_loss: 0.0264 - val_dice_coef: 0.9847
# Epoch 472/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0154 - dice_coef: 0.9904Epoch 00471: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0153 - dice_coef: 0.9907 - val_loss: 0.0293 - val_dice_coef: 0.9851
# Epoch 473/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0153 - dice_coef: 0.9905Epoch 00472: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0151 - dice_coef: 0.9906 - val_loss: 0.0382 - val_dice_coef: 0.9834
# Epoch 474/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0149 - dice_coef: 0.9910Epoch 00473: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0139 - dice_coef: 0.9915 - val_loss: 0.0434 - val_dice_coef: 0.9819
# Epoch 475/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0145 - dice_coef: 0.9912Epoch 00474: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0141 - dice_coef: 0.9913 - val_loss: 0.0328 - val_dice_coef: 0.9859
# Epoch 476/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0141 - dice_coef: 0.9916Epoch 00475: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0135 - dice_coef: 0.9918 - val_loss: 0.0320 - val_dice_coef: 0.9853
# Epoch 477/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0140 - dice_coef: 0.9916Epoch 00476: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0136 - dice_coef: 0.9917 - val_loss: 0.0294 - val_dice_coef: 0.9860
# Epoch 478/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0145 - dice_coef: 0.9912Epoch 00477: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0153 - dice_coef: 0.9909 - val_loss: 0.0290 - val_dice_coef: 0.9858
# Epoch 479/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0151 - dice_coef: 0.9909Epoch 00478: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0148 - dice_coef: 0.9911 - val_loss: 0.0365 - val_dice_coef: 0.9818
# Epoch 480/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0147 - dice_coef: 0.9904Epoch 00479: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0146 - dice_coef: 0.9907 - val_loss: 0.0326 - val_dice_coef: 0.9853
# Epoch 481/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9910Epoch 00480: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0140 - dice_coef: 0.9915 - val_loss: 0.0376 - val_dice_coef: 0.9826
# Epoch 482/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9911Epoch 00481: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0148 - dice_coef: 0.9910 - val_loss: 0.0310 - val_dice_coef: 0.9855
# Epoch 483/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0149 - dice_coef: 0.9911Epoch 00482: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0150 - dice_coef: 0.9910 - val_loss: 0.0264 - val_dice_coef: 0.9866
# Epoch 484/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0145 - dice_coef: 0.9912Epoch 00483: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0147 - dice_coef: 0.9910 - val_loss: 0.0352 - val_dice_coef: 0.9822
# Epoch 485/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9909Epoch 00484: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0141 - dice_coef: 0.9912 - val_loss: 0.0280 - val_dice_coef: 0.9871
# Epoch 486/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0148 - dice_coef: 0.9914Epoch 00485: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0149 - dice_coef: 0.9912 - val_loss: 0.0336 - val_dice_coef: 0.9840
# Epoch 487/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0140 - dice_coef: 0.9913Epoch 00486: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0138 - dice_coef: 0.9916 - val_loss: 0.0271 - val_dice_coef: 0.9876
# Epoch 488/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0144 - dice_coef: 0.9914Epoch 00487: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0146 - dice_coef: 0.9912 - val_loss: 0.0314 - val_dice_coef: 0.9843
# Epoch 489/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0144 - dice_coef: 0.9910Epoch 00488: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0139 - dice_coef: 0.9913 - val_loss: 0.0280 - val_dice_coef: 0.9866
# Epoch 490/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0136 - dice_coef: 0.9916Epoch 00489: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0131 - dice_coef: 0.9918 - val_loss: 0.0301 - val_dice_coef: 0.9861
# Epoch 491/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0138 - dice_coef: 0.9918Epoch 00490: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0147 - dice_coef: 0.9914 - val_loss: 0.0283 - val_dice_coef: 0.9865
# Epoch 492/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0137 - dice_coef: 0.9916Epoch 00491: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0143 - dice_coef: 0.9913 - val_loss: 0.0250 - val_dice_coef: 0.9869
# Epoch 493/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0138 - dice_coef: 0.9912Epoch 00492: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0145 - dice_coef: 0.9910 - val_loss: 0.0250 - val_dice_coef: 0.9871
# Epoch 494/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9912Epoch 00493: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0145 - dice_coef: 0.9912 - val_loss: 0.0342 - val_dice_coef: 0.9836
# Epoch 495/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0152 - dice_coef: 0.9905Epoch 00494: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0157 - dice_coef: 0.9903 - val_loss: 0.0247 - val_dice_coef: 0.9875
# Epoch 496/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0146 - dice_coef: 0.9908Epoch 00495: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0142 - dice_coef: 0.9910 - val_loss: 0.0287 - val_dice_coef: 0.9863
# Epoch 497/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0151 - dice_coef: 0.9913Epoch 00496: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0147 - dice_coef: 0.9914 - val_loss: 0.0305 - val_dice_coef: 0.9867
# Epoch 498/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0152 - dice_coef: 0.9911Epoch 00497: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0155 - dice_coef: 0.9912 - val_loss: 0.0259 - val_dice_coef: 0.9876
# Epoch 499/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0142 - dice_coef: 0.9908Epoch 00498: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0146 - dice_coef: 0.9904 - val_loss: 0.0280 - val_dice_coef: 0.9848
# Epoch 500/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0145 - dice_coef: 0.9909Epoch 00499: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0142 - dice_coef: 0.9911 - val_loss: 0.0283 - val_dice_coef: 0.9875

# %%
show_plots(hist)

# %%
import tensorflow as tf

model.load_weights(weight_file)

def calculate_dice(images, masks_true):
    dices = []
    masks_pred = np.concatenate([model.predict(image[None,:,:,:]) for image in images])
    for mask_true, mask_pred in zip(masks_true, masks_pred):
        y_true = mask_true.astype('float64')
        y_pred = mask_pred.astype('float64')
        dices.append(dice_coef_np(y_true.flatten(), y_pred.flatten()))
    print("Dice Average: {:.2f} Dice Stdev: {:.2f}".format(np.mean(dices), np.std(dices)))

# %%
print("Training Statistics(No Dropout)...")
calculate_dice(train_images, train_inner_masks)
print("Validation Statistics(No Dropout)...")
calculate_dice(validation_images, validation_inner_masks)
# Out:
# Training Statistics(No Dropout)...
# Dice Average: 0.98 Dice Stdev: 0.01
# Validation Statistics(No Dropout)...
# Dice Average: 0.99 Dice Stdev: 0.01

# %% [markdown]
# # View Predictions on Validation Set

# %%
def show_masks(images, i_masks_true):
    masks_pred = np.concatenate([model.predict(image[None,:,:,:]) for image in images])
    counter = 0
    for (image,i_mask,mask_pred) in zip(images,i_masks_true,masks_pred):
        plt.figure(figsize=(10,5))
        plt.subplot(1, 3, 1)
        plt.axis("off")
        plt.imshow(i_mask, cmap=plt.cm.gray)
        plt.subplot(1,3,2)
        plt.axis("off")
        plt.imshow(np.where(mask_pred[:,:,1]>0.5,255,0),cmap=plt.cm.gray)
        plt.subplot(1, 3, 3)
        plt.axis("off")
        plt.imshow(image[:,:,0], cmap=plt.cm.gray)
        counter += 1
        filename = "{:2d}.png".format(counter)
        plt.savefig(os.path.join(save_imgs_dir, filename))
        
show_masks(images[split_index:], inner_masks[split_index:])
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
