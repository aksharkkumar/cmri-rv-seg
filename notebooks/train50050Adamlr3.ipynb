# %% [markdown]
# # Training U-Net model
# ## 500 Epochs, 0.5 Dropout, Adam Optimizer, Learning Rate 1e-3

# %%
import sys
sys.path.append("..")
import os, re, glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from src import data,unet
# Out:
# Using TensorFlow backend.

# %%
from keras import utils
train_dir = "/home/ubuntu/trainingdata/TrainingSet"
weight_file = 'saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5'
save_imgs_dir = 'images/train50050DrpAdam3'

images = []
inner_masks = []
outer_masks = []

patient_directories = sorted(glob.glob(os.path.join(train_dir, "patient*")))

for patient_dir in patient_directories:
    imgdata = data.ImageData(patient_dir)
    images += imgdata.labeled_images
    inner_masks += imgdata.endo_masks
    outer_masks += imgdata.epi_masks

images = np.asarray(images)[:,:,:,None].astype('float64')
i_masks = np.asarray(inner_masks)
o_masks = np.asarray(outer_masks)

dims = i_masks.shape
classes = len(set(i_masks[0].flatten()))
new_shape = dims + (classes,)
i_masks = utils.to_categorical(i_masks).reshape(new_shape)
o_masks = utils.to_categorical(o_masks).reshape(new_shape)

def normalize(x, epsilon=1e-7, axis=(1,2)):
    x -= np.mean(x, axis=axis, keepdims=True)
    x /= np.std(x, axis=axis, keepdims=True) + epsilon
    
normalize(images,axis=(1,2))

print("There are %d total training images." % len(images))
print("There are %d total inner masks." % len(inner_masks))
print("There are %d total outer masks." % len(outer_masks))
# Out:
# There are 243 total training images.
# There are 243 total inner masks.
# There are 243 total outer masks.

# %%
height,width,_ = images[0].shape
dropout = 0.5
unet_conv = unet.UNet()

model = unet_conv.get_unet(height=height, width=width, channels=1,features=32,steps=3,dropout=dropout,padding='same')
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 216, 256, 1)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 216, 256, 32)  320         input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 216, 256, 32)  0           conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 216, 256, 32)  0           activation_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 216, 256, 32)  9248        dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 216, 256, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 216, 256, 32)  0           activation_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 108, 128, 32)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 108, 128, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 108, 128, 64)  0           conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 108, 128, 64)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 108, 128, 64)  36928       dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 108, 128, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 108, 128, 64)  0           activation_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 54, 64, 64)    0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 54, 64, 128)   73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 54, 64, 128)   0           conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 54, 64, 128)   0           activation_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 54, 64, 128)   147584      dropout_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 54, 64, 128)   0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 54, 64, 128)   0           activation_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 27, 32, 128)   0           dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 27, 32, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 27, 32, 256)   0           conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 27, 32, 256)   0           activation_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 27, 32, 256)   590080      dropout_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 27, 32, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 27, 32, 256)   0           activation_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 27, 32, 256)   590080      dropout_8[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 27, 32, 256)   0           conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 27, 32, 256)   0           activation_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 27, 32, 256)   590080      dropout_9[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 27, 32, 256)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 27, 32, 256)   0           activation_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTransp (None, 54, 64, 128)   131200      dropout_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 54, 64, 256)   0           conv2d_transpose_1[0][0]
#                                                                    conv2d_transpose_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 54, 64, 128)   295040      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 54, 64, 128)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, 54, 64, 128)   0           activation_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 54, 64, 128)   147584      dropout_11[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 54, 64, 128)   0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 54, 64, 128)   0           activation_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTransp (None, 108, 128, 64)  32832       dropout_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 108, 128, 128) 0           conv2d_transpose_2[0][0]
#                                                                    conv2d_transpose_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 108, 128, 64)  73792       concatenate_2[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 108, 128, 64)  0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 108, 128, 64)  0           activation_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 108, 128, 64)  36928       dropout_13[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 108, 128, 64)  0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 108, 128, 64)  0           activation_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTransp (None, 216, 256, 32)  8224        dropout_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 216, 256, 64)  0           conv2d_transpose_3[0][0]
#                                                                    conv2d_transpose_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 216, 256, 32)  18464       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 216, 256, 32)  0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 216, 256, 32)  0           activation_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 216, 256, 32)  9248        dropout_15[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 216, 256, 32)  0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 216, 256, 32)  0           activation_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 216, 256, 2)   66          dropout_16[0][0]
# ____________________________________________________________________________________________________
# lambda_1 (Lambda)                (None, 216, 256, 2)   0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 216, 256, 2)   0           lambda_1[0][0]
# ====================================================================================================
# Total params: 3,105,218
# Trainable params: 3,105,218
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from keras.optimizers import Adam, SGD
from keras import backend as K

def dice_coef(y_true, y_pred):
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    intersection = K.sum(flat_y_true * flat_y_pred)
    return (2. * intersection + 1.) / (K.sum(flat_y_true) + K.sum(flat_y_pred) + 1.)

def dice_coef_np(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection + 1.) / (np.sum(y_true) + np.sum(y_pred) + 1.)


def pixelwise_crossentropy(y_true, y_pred, weights=[0.5,0.5], epsilon=1e-8):
    ndim = K.ndim(y_pred)
    ncategory = K.int_shape(y_pred)[-1]
    # scale predictions so class probabilities of each pixel sum to 1
    y_pred /= K.sum(y_pred, axis=(ndim-1), keepdims=True)
    y_pred = K.clip(y_pred, epsilon, 1-epsilon)
    w = K.constant(weights) * (ncategory / sum(weights))
    # first, average over all axis except classes
    cross_entropies = -K.mean(y_true * K.log(y_pred), axis=tuple(range(ndim-1)))
    return K.sum(w * cross_entropies)


def show_plots(history):    
    plt.plot(history.history['dice_coef'])
    plt.plot(history.history['val_dice_coef'])
    plt.title('model dice')
    plt.ylabel('dice')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    plt.savefig(os.path.join(save_imgs_dir,"acc-loss-plot.png"))
model.compile(optimizer=Adam(lr=1e-3),loss=[pixelwise_crossentropy],metrics=[dice_coef])

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

from math import ceil

seed = 78

validation_split=0.2

epochs = 500
batch_size = 32


split_index = int((1 - validation_split) * len(images))

train_steps = ceil(split_index / batch_size)
val_steps = ceil((len(images)-split_index )/batch_size)

train_images = images[:split_index]
train_inner_masks = i_masks[:split_index]

validation_images = images[split_index:]
validation_inner_masks = i_masks[split_index:]


data_gen_args = dict(rotation_range=180,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     shear_range=0.1,
                     zoom_range=0.05,
                     fill_mode='nearest')

train_images_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**data_gen_args)


#seed = 1
#height,width,channels = train_images[0].shape
#print(train_images[0].shape)
#print(train_inner_masks[0].shape)
train_images_datagen.fit(train_images,augment=True,seed=seed)
train_masks_datagen.fit(train_inner_masks,augment=True,seed=seed)

train_images_generator = train_images_datagen.flow(train_images, y=None, seed=seed)
train_masks_generator = train_images_datagen.flow(train_inner_masks, y=None, seed=seed)


train_generator = zip(train_images_generator, train_masks_generator)
# Out:
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.8-py3.5.egg/keras/preprocessing/image.py:653: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (194, 216, 256, 2) (2 channels).
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.8-py3.5.egg/keras/preprocessing/image.py:787: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (194, 216, 256, 2) (2 channels).

# %%
checkpointer = ModelCheckpoint(filepath=weight_file, verbose=1, save_best_only=True)

hist = model.fit_generator(train_generator,steps_per_epoch=train_steps,epochs=epochs,verbose=1,callbacks=[checkpointer],
                   validation_data=(validation_images,validation_inner_masks),validation_steps=val_steps)
# Out:
# Epoch 1/500
# 6/7 [========================>.....] - ETA: 3s - loss: 0.6867 - dice_coef: 0.5048Epoch 00000: val_loss improved from inf to 0.55949, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 23s - loss: 0.6737 - dice_coef: 0.5117 - val_loss: 0.5595 - val_dice_coef: 0.5726
# Epoch 2/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.4349 - dice_coef: 0.7664Epoch 00001: val_loss improved from 0.55949 to 0.34533, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.4225 - dice_coef: 0.7639 - val_loss: 0.3453 - val_dice_coef: 0.7196
# Epoch 3/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.2483 - dice_coef: 0.8856Epoch 00002: val_loss improved from 0.34533 to 0.25121, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.2592 - dice_coef: 0.8772 - val_loss: 0.2512 - val_dice_coef: 0.8039
# Epoch 4/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.2289 - dice_coef: 0.8777Epoch 00003: val_loss improved from 0.25121 to 0.21426, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.2339 - dice_coef: 0.8793 - val_loss: 0.2143 - val_dice_coef: 0.8437
# Epoch 5/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.2110 - dice_coef: 0.8846Epoch 00004: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.2045 - dice_coef: 0.8898 - val_loss: 0.2296 - val_dice_coef: 0.8238
# Epoch 6/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1970 - dice_coef: 0.8934Epoch 00005: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1901 - dice_coef: 0.8975 - val_loss: 0.2443 - val_dice_coef: 0.8076
# Epoch 7/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1870 - dice_coef: 0.8951Epoch 00006: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1948 - dice_coef: 0.8953 - val_loss: 0.2457 - val_dice_coef: 0.8052
# Epoch 8/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1830 - dice_coef: 0.8915Epoch 00007: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1846 - dice_coef: 0.8931 - val_loss: 0.2395 - val_dice_coef: 0.8102
# Epoch 9/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1776 - dice_coef: 0.8950Epoch 00008: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1821 - dice_coef: 0.8956 - val_loss: 0.2346 - val_dice_coef: 0.8147
# Epoch 10/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1738 - dice_coef: 0.9010Epoch 00009: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1777 - dice_coef: 0.9002 - val_loss: 0.2528 - val_dice_coef: 0.7979
# Epoch 11/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1685 - dice_coef: 0.9037Epoch 00010: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1692 - dice_coef: 0.9031 - val_loss: 0.2821 - val_dice_coef: 0.7712
# Epoch 12/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1608 - dice_coef: 0.9082Epoch 00011: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1620 - dice_coef: 0.9091 - val_loss: 0.2894 - val_dice_coef: 0.7638
# Epoch 13/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1527 - dice_coef: 0.9105Epoch 00012: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1540 - dice_coef: 0.9110 - val_loss: 0.3109 - val_dice_coef: 0.7455
# Epoch 14/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1504 - dice_coef: 0.9090Epoch 00013: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1495 - dice_coef: 0.9119 - val_loss: 0.3305 - val_dice_coef: 0.7297
# Epoch 15/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1564 - dice_coef: 0.9066Epoch 00014: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1562 - dice_coef: 0.9048 - val_loss: 0.3143 - val_dice_coef: 0.7424
# Epoch 16/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1471 - dice_coef: 0.9184Epoch 00015: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1442 - dice_coef: 0.9197 - val_loss: 0.3288 - val_dice_coef: 0.7305
# Epoch 17/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1393 - dice_coef: 0.9153Epoch 00016: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1419 - dice_coef: 0.9138 - val_loss: 0.3210 - val_dice_coef: 0.7368
# Epoch 18/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1326 - dice_coef: 0.9218Epoch 00017: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1396 - dice_coef: 0.9166 - val_loss: 0.3281 - val_dice_coef: 0.7331
# Epoch 19/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1383 - dice_coef: 0.9162Epoch 00018: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1359 - dice_coef: 0.9176 - val_loss: 0.3434 - val_dice_coef: 0.7219
# Epoch 20/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1300 - dice_coef: 0.9209Epoch 00019: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1278 - dice_coef: 0.9230 - val_loss: 0.3480 - val_dice_coef: 0.7188
# Epoch 21/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1295 - dice_coef: 0.9212Epoch 00020: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1338 - dice_coef: 0.9177 - val_loss: 0.3468 - val_dice_coef: 0.7192
# Epoch 22/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1246 - dice_coef: 0.9248Epoch 00021: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1282 - dice_coef: 0.9243 - val_loss: 0.3775 - val_dice_coef: 0.6967
# Epoch 23/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1295 - dice_coef: 0.9196Epoch 00022: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1270 - dice_coef: 0.9210 - val_loss: 0.3446 - val_dice_coef: 0.7222
# Epoch 24/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1272 - dice_coef: 0.9250Epoch 00023: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1262 - dice_coef: 0.9236 - val_loss: 0.3726 - val_dice_coef: 0.7028
# Epoch 25/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1236 - dice_coef: 0.9256Epoch 00024: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1248 - dice_coef: 0.9243 - val_loss: 0.4128 - val_dice_coef: 0.6742
# Epoch 26/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1220 - dice_coef: 0.9245Epoch 00025: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1237 - dice_coef: 0.9222 - val_loss: 0.3639 - val_dice_coef: 0.7109
# Epoch 27/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1203 - dice_coef: 0.9254Epoch 00026: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1174 - dice_coef: 0.9292 - val_loss: 0.3973 - val_dice_coef: 0.6864
# Epoch 28/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1240 - dice_coef: 0.9247Epoch 00027: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1142 - dice_coef: 0.9299 - val_loss: 0.3886 - val_dice_coef: 0.6926
# Epoch 29/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1225 - dice_coef: 0.9270Epoch 00028: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1209 - dice_coef: 0.9270 - val_loss: 0.3610 - val_dice_coef: 0.7117
# Epoch 30/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1252 - dice_coef: 0.9266Epoch 00029: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1308 - dice_coef: 0.9211 - val_loss: 0.3932 - val_dice_coef: 0.6874
# Epoch 31/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1169 - dice_coef: 0.9271Epoch 00030: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1177 - dice_coef: 0.9258 - val_loss: 0.3437 - val_dice_coef: 0.7242
# Epoch 32/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1215 - dice_coef: 0.9267Epoch 00031: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1138 - dice_coef: 0.9304 - val_loss: 0.3092 - val_dice_coef: 0.7511
# Epoch 33/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1178 - dice_coef: 0.9282Epoch 00032: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1159 - dice_coef: 0.9303 - val_loss: 0.3529 - val_dice_coef: 0.7188
# Epoch 34/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1159 - dice_coef: 0.9289Epoch 00033: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1130 - dice_coef: 0.9296 - val_loss: 0.3789 - val_dice_coef: 0.7002
# Epoch 35/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1143 - dice_coef: 0.9281Epoch 00034: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1194 - dice_coef: 0.9264 - val_loss: 0.3780 - val_dice_coef: 0.7001
# Epoch 36/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1149 - dice_coef: 0.9286Epoch 00035: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1165 - dice_coef: 0.9274 - val_loss: 0.4439 - val_dice_coef: 0.6527
# Epoch 37/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1293 - dice_coef: 0.9188Epoch 00036: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1294 - dice_coef: 0.9208 - val_loss: 0.4515 - val_dice_coef: 0.6458
# Epoch 38/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1216 - dice_coef: 0.9239Epoch 00037: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1232 - dice_coef: 0.9221 - val_loss: 0.3654 - val_dice_coef: 0.7070
# Epoch 39/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1164 - dice_coef: 0.9284Epoch 00038: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1139 - dice_coef: 0.9289 - val_loss: 0.2865 - val_dice_coef: 0.7687
# Epoch 40/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1181 - dice_coef: 0.9292Epoch 00039: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1166 - dice_coef: 0.9295 - val_loss: 0.2766 - val_dice_coef: 0.7767
# Epoch 41/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1126 - dice_coef: 0.9304Epoch 00040: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1064 - dice_coef: 0.9343 - val_loss: 0.2842 - val_dice_coef: 0.7699
# Epoch 42/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1158 - dice_coef: 0.9281Epoch 00041: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1095 - dice_coef: 0.9334 - val_loss: 0.3068 - val_dice_coef: 0.7518
# Epoch 43/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1125 - dice_coef: 0.9313Epoch 00042: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1099 - dice_coef: 0.9324 - val_loss: 0.3009 - val_dice_coef: 0.7586
# Epoch 44/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1120 - dice_coef: 0.9284Epoch 00043: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1147 - dice_coef: 0.9305 - val_loss: 0.3367 - val_dice_coef: 0.7316
# Epoch 45/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1161 - dice_coef: 0.9270Epoch 00044: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1200 - dice_coef: 0.9246 - val_loss: 0.3404 - val_dice_coef: 0.7266
# Epoch 46/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1145 - dice_coef: 0.9293Epoch 00045: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1245 - dice_coef: 0.9282 - val_loss: 0.4288 - val_dice_coef: 0.6596
# Epoch 47/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1274 - dice_coef: 0.9186Epoch 00046: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1284 - dice_coef: 0.9168 - val_loss: 0.2406 - val_dice_coef: 0.8029
# Epoch 48/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1149 - dice_coef: 0.9315Epoch 00047: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1241 - dice_coef: 0.9298 - val_loss: 0.3150 - val_dice_coef: 0.7473
# Epoch 49/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1325 - dice_coef: 0.9195Epoch 00048: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1329 - dice_coef: 0.9169 - val_loss: 0.4011 - val_dice_coef: 0.6773
# Epoch 50/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1258 - dice_coef: 0.9235Epoch 00049: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1261 - dice_coef: 0.9216 - val_loss: 0.3322 - val_dice_coef: 0.7302
# Epoch 51/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1158 - dice_coef: 0.9301Epoch 00050: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1157 - dice_coef: 0.9284 - val_loss: 0.3245 - val_dice_coef: 0.7393
# Epoch 52/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1140 - dice_coef: 0.9298Epoch 00051: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1169 - dice_coef: 0.9261 - val_loss: 0.2842 - val_dice_coef: 0.7729
# Epoch 53/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1097 - dice_coef: 0.9314Epoch 00052: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1045 - dice_coef: 0.9335 - val_loss: 0.2334 - val_dice_coef: 0.8122
# Epoch 54/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1127 - dice_coef: 0.9308Epoch 00053: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1066 - dice_coef: 0.9340 - val_loss: 0.2516 - val_dice_coef: 0.7968
# Epoch 55/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1167 - dice_coef: 0.9294Epoch 00054: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1191 - dice_coef: 0.9261 - val_loss: 0.2683 - val_dice_coef: 0.7821
# Epoch 56/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1090 - dice_coef: 0.9320Epoch 00055: val_loss improved from 0.21426 to 0.20419, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1154 - dice_coef: 0.9291 - val_loss: 0.2042 - val_dice_coef: 0.8363
# Epoch 57/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1080 - dice_coef: 0.9334Epoch 00056: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1055 - dice_coef: 0.9337 - val_loss: 0.2384 - val_dice_coef: 0.8050
# Epoch 58/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1079 - dice_coef: 0.9327Epoch 00057: val_loss improved from 0.20419 to 0.19904, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.1044 - dice_coef: 0.9352 - val_loss: 0.1990 - val_dice_coef: 0.8391
# Epoch 59/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1067 - dice_coef: 0.9333Epoch 00058: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1010 - dice_coef: 0.9366 - val_loss: 0.2186 - val_dice_coef: 0.8216
# Epoch 60/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1027 - dice_coef: 0.9357Epoch 00059: val_loss improved from 0.19904 to 0.17660, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0998 - dice_coef: 0.9377 - val_loss: 0.1766 - val_dice_coef: 0.8589
# Epoch 61/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1028 - dice_coef: 0.9355Epoch 00060: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1071 - dice_coef: 0.9334 - val_loss: 0.2371 - val_dice_coef: 0.8093
# Epoch 62/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1292 - dice_coef: 0.9193Epoch 00061: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1317 - dice_coef: 0.9166 - val_loss: 0.3155 - val_dice_coef: 0.7429
# Epoch 63/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1171 - dice_coef: 0.9288Epoch 00062: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1140 - dice_coef: 0.9309 - val_loss: 0.3013 - val_dice_coef: 0.7540
# Epoch 64/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1132 - dice_coef: 0.9294Epoch 00063: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1096 - dice_coef: 0.9323 - val_loss: 0.2668 - val_dice_coef: 0.7834
# Epoch 65/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1110 - dice_coef: 0.9295Epoch 00064: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1138 - dice_coef: 0.9299 - val_loss: 0.2878 - val_dice_coef: 0.7660
# Epoch 66/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1112 - dice_coef: 0.9294Epoch 00065: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1095 - dice_coef: 0.9297 - val_loss: 0.2751 - val_dice_coef: 0.7761
# Epoch 67/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1114 - dice_coef: 0.9305Epoch 00066: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1098 - dice_coef: 0.9325 - val_loss: 0.2756 - val_dice_coef: 0.7765
# Epoch 68/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1098 - dice_coef: 0.9298Epoch 00067: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1083 - dice_coef: 0.9300 - val_loss: 0.1769 - val_dice_coef: 0.8806
# Epoch 69/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1083 - dice_coef: 0.9340Epoch 00068: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1048 - dice_coef: 0.9355 - val_loss: 0.2033 - val_dice_coef: 0.8385
# Epoch 70/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1033 - dice_coef: 0.9355Epoch 00069: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1060 - dice_coef: 0.9336 - val_loss: 0.2070 - val_dice_coef: 0.8389
# Epoch 71/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1083 - dice_coef: 0.9330Epoch 00070: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1112 - dice_coef: 0.9297 - val_loss: 0.2019 - val_dice_coef: 0.8521
# Epoch 72/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1020 - dice_coef: 0.9337Epoch 00071: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1068 - dice_coef: 0.9318 - val_loss: 0.1854 - val_dice_coef: 0.8970
# Epoch 73/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1050 - dice_coef: 0.9349Epoch 00072: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.1022 - dice_coef: 0.9369 - val_loss: 0.2157 - val_dice_coef: 0.8296
# Epoch 74/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1054 - dice_coef: 0.9334Epoch 00073: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1041 - dice_coef: 0.9349 - val_loss: 0.2605 - val_dice_coef: 0.7931
# Epoch 75/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1131 - dice_coef: 0.9304Epoch 00074: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1101 - dice_coef: 0.9311 - val_loss: 0.2858 - val_dice_coef: 0.7676
# Epoch 76/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1072 - dice_coef: 0.9329Epoch 00075: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1041 - dice_coef: 0.9340 - val_loss: 0.2605 - val_dice_coef: 0.7887
# Epoch 77/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1049 - dice_coef: 0.9351Epoch 00076: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1038 - dice_coef: 0.9352 - val_loss: 0.2516 - val_dice_coef: 0.7967
# Epoch 78/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0993 - dice_coef: 0.9362Epoch 00077: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0953 - dice_coef: 0.9384 - val_loss: 0.1839 - val_dice_coef: 0.8530
# Epoch 79/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0951 - dice_coef: 0.9411Epoch 00078: val_loss improved from 0.17660 to 0.15006, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0944 - dice_coef: 0.9406 - val_loss: 0.1501 - val_dice_coef: 0.8850
# Epoch 80/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1115 - dice_coef: 0.9341Epoch 00079: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1103 - dice_coef: 0.9349 - val_loss: 0.2794 - val_dice_coef: 0.7719
# Epoch 81/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1066 - dice_coef: 0.9323Epoch 00080: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1083 - dice_coef: 0.9315 - val_loss: 0.2013 - val_dice_coef: 0.8397
# Epoch 82/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1004 - dice_coef: 0.9372Epoch 00081: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0970 - dice_coef: 0.9384 - val_loss: 0.1969 - val_dice_coef: 0.8427
# Epoch 83/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1014 - dice_coef: 0.9360Epoch 00082: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1007 - dice_coef: 0.9360 - val_loss: 0.1620 - val_dice_coef: 0.8777
# Epoch 84/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0996 - dice_coef: 0.9384Epoch 00083: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0956 - dice_coef: 0.9404 - val_loss: 0.1589 - val_dice_coef: 0.8777
# Epoch 85/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1006 - dice_coef: 0.9365Epoch 00084: val_loss improved from 0.15006 to 0.14377, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0947 - dice_coef: 0.9396 - val_loss: 0.1438 - val_dice_coef: 0.8941
# Epoch 86/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1007 - dice_coef: 0.9375Epoch 00085: val_loss improved from 0.14377 to 0.13727, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0969 - dice_coef: 0.9397 - val_loss: 0.1373 - val_dice_coef: 0.9012
# Epoch 87/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1003 - dice_coef: 0.9382Epoch 00086: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0989 - dice_coef: 0.9408 - val_loss: 0.1537 - val_dice_coef: 0.8833
# Epoch 88/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0974 - dice_coef: 0.9388Epoch 00087: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0998 - dice_coef: 0.9368 - val_loss: 0.1879 - val_dice_coef: 0.8500
# Epoch 89/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0977 - dice_coef: 0.9380Epoch 00088: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1006 - dice_coef: 0.9366 - val_loss: 0.1616 - val_dice_coef: 0.8732
# Epoch 90/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0978 - dice_coef: 0.9372Epoch 00089: val_loss improved from 0.13727 to 0.13469, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0991 - dice_coef: 0.9356 - val_loss: 0.1347 - val_dice_coef: 0.9145
# Epoch 91/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0944 - dice_coef: 0.9415Epoch 00090: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0919 - dice_coef: 0.9424 - val_loss: 0.1374 - val_dice_coef: 0.9263
# Epoch 92/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0925 - dice_coef: 0.9408Epoch 00091: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0986 - dice_coef: 0.9370 - val_loss: 0.2065 - val_dice_coef: 0.9500
# Epoch 93/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0944 - dice_coef: 0.9410Epoch 00092: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0975 - dice_coef: 0.9380 - val_loss: 0.2249 - val_dice_coef: 0.9482
# Epoch 94/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0965 - dice_coef: 0.9430Epoch 00093: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0962 - dice_coef: 0.9439 - val_loss: 0.1631 - val_dice_coef: 0.8991
# Epoch 95/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0978 - dice_coef: 0.9383Epoch 00094: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0915 - dice_coef: 0.9420 - val_loss: 0.1785 - val_dice_coef: 0.9160
# Epoch 96/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0914 - dice_coef: 0.9429Epoch 00095: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0913 - dice_coef: 0.9438 - val_loss: 0.2593 - val_dice_coef: 0.9385
# Epoch 97/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0903 - dice_coef: 0.9437Epoch 00096: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0866 - dice_coef: 0.9452 - val_loss: 0.4455 - val_dice_coef: 0.9518
# Epoch 98/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0890 - dice_coef: 0.9448Epoch 00097: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0887 - dice_coef: 0.9448 - val_loss: 0.3227 - val_dice_coef: 0.9424
# Epoch 99/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0851 - dice_coef: 0.9488Epoch 00098: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0837 - dice_coef: 0.9492 - val_loss: 0.3294 - val_dice_coef: 0.9508
# Epoch 100/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0947 - dice_coef: 0.9452Epoch 00099: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0926 - dice_coef: 0.9461 - val_loss: 0.2435 - val_dice_coef: 0.8942
# Epoch 101/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0846 - dice_coef: 0.9466Epoch 00100: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0838 - dice_coef: 0.9473 - val_loss: 0.4423 - val_dice_coef: 0.9499
# Epoch 102/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0945 - dice_coef: 0.9454Epoch 00101: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0910 - dice_coef: 0.9470 - val_loss: 0.3189 - val_dice_coef: 0.9417
# Epoch 103/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0929 - dice_coef: 0.9428Epoch 00102: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0943 - dice_coef: 0.9438 - val_loss: 0.2180 - val_dice_coef: 0.9273
# Epoch 104/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0864 - dice_coef: 0.9461Epoch 00103: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0896 - dice_coef: 0.9490 - val_loss: 0.2172 - val_dice_coef: 0.8876
# Epoch 105/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.1033 - dice_coef: 0.9363Epoch 00104: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0949 - dice_coef: 0.9413 - val_loss: 0.1655 - val_dice_coef: 0.8745
# Epoch 106/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.1068 - dice_coef: 0.9367Epoch 00105: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.1008 - dice_coef: 0.9396 - val_loss: 0.1989 - val_dice_coef: 0.8471
# Epoch 107/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0897 - dice_coef: 0.9432Epoch 00106: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0941 - dice_coef: 0.9419 - val_loss: 0.1732 - val_dice_coef: 0.8699
# Epoch 108/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0939 - dice_coef: 0.9429Epoch 00107: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0924 - dice_coef: 0.9438 - val_loss: 0.1697 - val_dice_coef: 0.8786
# Epoch 109/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0936 - dice_coef: 0.9401Epoch 00108: val_loss improved from 0.13469 to 0.11533, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0910 - dice_coef: 0.9416 - val_loss: 0.1153 - val_dice_coef: 0.9424
# Epoch 110/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0936 - dice_coef: 0.9439Epoch 00109: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0959 - dice_coef: 0.9409 - val_loss: 0.2822 - val_dice_coef: 0.9554
# Epoch 111/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0912 - dice_coef: 0.9471Epoch 00110: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0868 - dice_coef: 0.9491 - val_loss: 0.1386 - val_dice_coef: 0.9353
# Epoch 112/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0868 - dice_coef: 0.9490Epoch 00111: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0903 - dice_coef: 0.9482 - val_loss: 0.1569 - val_dice_coef: 0.9061
# Epoch 113/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0860 - dice_coef: 0.9463Epoch 00112: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0843 - dice_coef: 0.9476 - val_loss: 0.2989 - val_dice_coef: 0.9518
# Epoch 114/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0864 - dice_coef: 0.9498Epoch 00113: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0875 - dice_coef: 0.9481 - val_loss: 0.3633 - val_dice_coef: 0.9516
# Epoch 115/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0843 - dice_coef: 0.9544Epoch 00114: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0831 - dice_coef: 0.9531 - val_loss: 0.3066 - val_dice_coef: 0.9457
# Epoch 116/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0784 - dice_coef: 0.9523Epoch 00115: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0845 - dice_coef: 0.9491 - val_loss: 0.3334 - val_dice_coef: 0.9401
# Epoch 117/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0911 - dice_coef: 0.9455Epoch 00116: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0913 - dice_coef: 0.9445 - val_loss: 0.1833 - val_dice_coef: 0.9135
# Epoch 118/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0750 - dice_coef: 0.9584Epoch 00117: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0725 - dice_coef: 0.9595 - val_loss: 0.5941 - val_dice_coef: 0.9590
# Epoch 119/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0780 - dice_coef: 0.9561Epoch 00118: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0778 - dice_coef: 0.9551 - val_loss: 0.3304 - val_dice_coef: 0.9427
# Epoch 120/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0680 - dice_coef: 0.9579Epoch 00119: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0649 - dice_coef: 0.9595 - val_loss: 0.2903 - val_dice_coef: 0.9462
# Epoch 121/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0709 - dice_coef: 0.9622Epoch 00120: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0725 - dice_coef: 0.9626 - val_loss: 0.5986 - val_dice_coef: 0.9536
# Epoch 122/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0791 - dice_coef: 0.9490Epoch 00121: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0752 - dice_coef: 0.9518 - val_loss: 0.3910 - val_dice_coef: 0.9523
# Epoch 123/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0685 - dice_coef: 0.9644Epoch 00122: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0653 - dice_coef: 0.9654 - val_loss: 0.5663 - val_dice_coef: 0.9568
# Epoch 124/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0715 - dice_coef: 0.9604Epoch 00123: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0655 - dice_coef: 0.9631 - val_loss: 0.2912 - val_dice_coef: 0.9321
# Epoch 125/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0678 - dice_coef: 0.9584Epoch 00124: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0652 - dice_coef: 0.9589 - val_loss: 0.3159 - val_dice_coef: 0.9323
# Epoch 126/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0669 - dice_coef: 0.9655Epoch 00125: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0661 - dice_coef: 0.9651 - val_loss: 0.6523 - val_dice_coef: 0.9571
# Epoch 127/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0636 - dice_coef: 0.9644Epoch 00126: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0597 - dice_coef: 0.9664 - val_loss: 0.2026 - val_dice_coef: 0.9269
# Epoch 128/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0668 - dice_coef: 0.9612Epoch 00127: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0661 - dice_coef: 0.9611 - val_loss: 0.1442 - val_dice_coef: 0.9361
# Epoch 129/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0648 - dice_coef: 0.9620Epoch 00128: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0632 - dice_coef: 0.9625 - val_loss: 0.2031 - val_dice_coef: 0.9426
# Epoch 130/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0647 - dice_coef: 0.9634Epoch 00129: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0626 - dice_coef: 0.9633 - val_loss: 0.3560 - val_dice_coef: 0.9522
# Epoch 131/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0653 - dice_coef: 0.9651Epoch 00130: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0664 - dice_coef: 0.9641 - val_loss: 0.4203 - val_dice_coef: 0.9475
# Epoch 132/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0837 - dice_coef: 0.9506Epoch 00131: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0812 - dice_coef: 0.9515 - val_loss: 0.1239 - val_dice_coef: 0.9056
# Epoch 133/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0715 - dice_coef: 0.9618Epoch 00132: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0704 - dice_coef: 0.9613 - val_loss: 0.1233 - val_dice_coef: 0.9178
# Epoch 134/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0718 - dice_coef: 0.9611Epoch 00133: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0733 - dice_coef: 0.9587 - val_loss: 0.1347 - val_dice_coef: 0.9057
# Epoch 135/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0691 - dice_coef: 0.9584Epoch 00134: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0666 - dice_coef: 0.9599 - val_loss: 0.1288 - val_dice_coef: 0.9273
# Epoch 136/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0606 - dice_coef: 0.9666Epoch 00135: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0701 - dice_coef: 0.9620 - val_loss: 0.2384 - val_dice_coef: 0.9532
# Epoch 137/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0706 - dice_coef: 0.9602Epoch 00136: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0697 - dice_coef: 0.9595 - val_loss: 0.1519 - val_dice_coef: 0.8903
# Epoch 138/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0672 - dice_coef: 0.9633Epoch 00137: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0650 - dice_coef: 0.9632 - val_loss: 0.1401 - val_dice_coef: 0.9129
# Epoch 139/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0626 - dice_coef: 0.9640Epoch 00138: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0635 - dice_coef: 0.9631 - val_loss: 0.1657 - val_dice_coef: 0.9351
# Epoch 140/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0585 - dice_coef: 0.9656Epoch 00139: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0567 - dice_coef: 0.9667 - val_loss: 0.2009 - val_dice_coef: 0.9444
# Epoch 141/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0540 - dice_coef: 0.9706Epoch 00140: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0539 - dice_coef: 0.9705 - val_loss: 0.1633 - val_dice_coef: 0.9344
# Epoch 142/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0526 - dice_coef: 0.9697Epoch 00141: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0523 - dice_coef: 0.9712 - val_loss: 0.1739 - val_dice_coef: 0.9374
# Epoch 143/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0528 - dice_coef: 0.9683Epoch 00142: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0502 - dice_coef: 0.9693 - val_loss: 0.1674 - val_dice_coef: 0.9466
# Epoch 144/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0535 - dice_coef: 0.9724Epoch 00143: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0529 - dice_coef: 0.9712 - val_loss: 0.4156 - val_dice_coef: 0.9561
# Epoch 145/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0571 - dice_coef: 0.9678Epoch 00144: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0602 - dice_coef: 0.9693 - val_loss: 0.1559 - val_dice_coef: 0.9374
# Epoch 146/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0595 - dice_coef: 0.9624Epoch 00145: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0591 - dice_coef: 0.9624 - val_loss: 0.1738 - val_dice_coef: 0.9405
# Epoch 147/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0572 - dice_coef: 0.9705Epoch 00146: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0587 - dice_coef: 0.9701 - val_loss: 0.2874 - val_dice_coef: 0.9568
# Epoch 148/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0576 - dice_coef: 0.9678Epoch 00147: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0579 - dice_coef: 0.9670 - val_loss: 0.2808 - val_dice_coef: 0.9497
# Epoch 149/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0534 - dice_coef: 0.9669Epoch 00148: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0516 - dice_coef: 0.9679 - val_loss: 0.4431 - val_dice_coef: 0.9575
# Epoch 150/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0569 - dice_coef: 0.9712Epoch 00149: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0564 - dice_coef: 0.9703 - val_loss: 0.2095 - val_dice_coef: 0.9425
# Epoch 151/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0550 - dice_coef: 0.9698Epoch 00150: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0577 - dice_coef: 0.9679 - val_loss: 0.1763 - val_dice_coef: 0.9270
# Epoch 152/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0610 - dice_coef: 0.9638Epoch 00151: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0668 - dice_coef: 0.9602 - val_loss: 0.1831 - val_dice_coef: 0.9427
# Epoch 153/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0642 - dice_coef: 0.9662Epoch 00152: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0619 - dice_coef: 0.9663 - val_loss: 0.1644 - val_dice_coef: 0.9415
# Epoch 154/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0628 - dice_coef: 0.9639Epoch 00153: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0610 - dice_coef: 0.9637 - val_loss: 0.1654 - val_dice_coef: 0.9498
# Epoch 155/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0581 - dice_coef: 0.9689Epoch 00154: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0564 - dice_coef: 0.9705 - val_loss: 0.1470 - val_dice_coef: 0.9507
# Epoch 156/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0530 - dice_coef: 0.9700Epoch 00155: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0536 - dice_coef: 0.9693 - val_loss: 0.1936 - val_dice_coef: 0.9486
# Epoch 157/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0502 - dice_coef: 0.9710Epoch 00156: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0553 - dice_coef: 0.9690 - val_loss: 0.1771 - val_dice_coef: 0.9498
# Epoch 158/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0520 - dice_coef: 0.9709Epoch 00157: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0509 - dice_coef: 0.9712 - val_loss: 0.1279 - val_dice_coef: 0.9331
# Epoch 159/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0541 - dice_coef: 0.9688Epoch 00158: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0555 - dice_coef: 0.9675 - val_loss: 0.1231 - val_dice_coef: 0.9402
# Epoch 160/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0561 - dice_coef: 0.9672Epoch 00159: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0541 - dice_coef: 0.9676 - val_loss: 0.1427 - val_dice_coef: 0.9456
# Epoch 161/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0508 - dice_coef: 0.9733Epoch 00160: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0490 - dice_coef: 0.9733 - val_loss: 0.1831 - val_dice_coef: 0.9528
# Epoch 162/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0448 - dice_coef: 0.9746Epoch 00161: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0465 - dice_coef: 0.9731 - val_loss: 0.3106 - val_dice_coef: 0.9560
# Epoch 163/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0472 - dice_coef: 0.9742Epoch 00162: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0459 - dice_coef: 0.9741 - val_loss: 0.2419 - val_dice_coef: 0.9537
# Epoch 164/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0435 - dice_coef: 0.9755Epoch 00163: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0439 - dice_coef: 0.9753 - val_loss: 0.4406 - val_dice_coef: 0.9582
# Epoch 165/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0472 - dice_coef: 0.9724Epoch 00164: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0451 - dice_coef: 0.9730 - val_loss: 0.4366 - val_dice_coef: 0.9581
# Epoch 166/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0457 - dice_coef: 0.9751Epoch 00165: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0449 - dice_coef: 0.9749 - val_loss: 0.1572 - val_dice_coef: 0.9563
# Epoch 167/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0453 - dice_coef: 0.9763Epoch 00166: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0424 - dice_coef: 0.9774 - val_loss: 0.1516 - val_dice_coef: 0.9486
# Epoch 168/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0461 - dice_coef: 0.9722Epoch 00167: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0446 - dice_coef: 0.9730 - val_loss: 0.1491 - val_dice_coef: 0.9476
# Epoch 169/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0430 - dice_coef: 0.9759Epoch 00168: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0488 - dice_coef: 0.9737 - val_loss: 0.1955 - val_dice_coef: 0.9548
# Epoch 170/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0472 - dice_coef: 0.9727Epoch 00169: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0467 - dice_coef: 0.9723 - val_loss: 0.1391 - val_dice_coef: 0.9367
# Epoch 171/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0498 - dice_coef: 0.9718Epoch 00170: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0476 - dice_coef: 0.9728 - val_loss: 0.2035 - val_dice_coef: 0.9529
# Epoch 172/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0507 - dice_coef: 0.9722Epoch 00171: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0562 - dice_coef: 0.9695 - val_loss: 0.1350 - val_dice_coef: 0.9428
# Epoch 173/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0472 - dice_coef: 0.9707Epoch 00172: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0471 - dice_coef: 0.9705 - val_loss: 0.2935 - val_dice_coef: 0.9528
# Epoch 174/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0451 - dice_coef: 0.9743Epoch 00173: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0450 - dice_coef: 0.9746 - val_loss: 0.2304 - val_dice_coef: 0.9567
# Epoch 175/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0538 - dice_coef: 0.9735Epoch 00174: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0588 - dice_coef: 0.9702 - val_loss: 0.1585 - val_dice_coef: 0.9064
# Epoch 176/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0589 - dice_coef: 0.9643Epoch 00175: val_loss improved from 0.11533 to 0.09730, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0557 - dice_coef: 0.9662 - val_loss: 0.0973 - val_dice_coef: 0.9383
# Epoch 177/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0492 - dice_coef: 0.9711Epoch 00176: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0510 - dice_coef: 0.9706 - val_loss: 0.1226 - val_dice_coef: 0.9405
# Epoch 178/500
# 6/7 [========================>.....] - ETA: 2s - loss: 0.0508 - dice_coef: 0.9730Epoch 00177: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0507 - dice_coef: 0.9723 - val_loss: 0.1142 - val_dice_coef: 0.9222
# Epoch 179/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0503 - dice_coef: 0.9713Epoch 00178: val_loss improved from 0.09730 to 0.09272, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0546 - dice_coef: 0.9690 - val_loss: 0.0927 - val_dice_coef: 0.9396
# Epoch 180/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0509 - dice_coef: 0.9718Epoch 00179: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0524 - dice_coef: 0.9718 - val_loss: 0.1202 - val_dice_coef: 0.9322
# Epoch 181/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0510 - dice_coef: 0.9693Epoch 00180: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0489 - dice_coef: 0.9704 - val_loss: 0.1767 - val_dice_coef: 0.9432
# Epoch 182/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0456 - dice_coef: 0.9742Epoch 00181: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0458 - dice_coef: 0.9744 - val_loss: 0.2590 - val_dice_coef: 0.9528
# Epoch 183/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0425 - dice_coef: 0.9761Epoch 00182: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0423 - dice_coef: 0.9761 - val_loss: 0.2124 - val_dice_coef: 0.9451
# Epoch 184/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0417 - dice_coef: 0.9753Epoch 00183: val_loss did not improve
# 7/7 [==============================] - 13s - loss: 0.0430 - dice_coef: 0.9746 - val_loss: 0.1835 - val_dice_coef: 0.9392
# Epoch 185/500
# ...
# 7/7 [==============================] - 12s - loss: 0.0259 - dice_coef: 0.9842 - val_loss: 0.0500 - val_dice_coef: 0.9762
# Epoch 440/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0255 - dice_coef: 0.9861Epoch 00439: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0258 - dice_coef: 0.9859 - val_loss: 0.0541 - val_dice_coef: 0.9678
# Epoch 441/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0251 - dice_coef: 0.9859Epoch 00440: val_loss improved from 0.04791 to 0.04419, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0415 - dice_coef: 0.9816 - val_loss: 0.0442 - val_dice_coef: 0.9712
# Epoch 442/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0613 - dice_coef: 0.9629Epoch 00441: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0641 - dice_coef: 0.9605 - val_loss: 0.1035 - val_dice_coef: 0.9234
# Epoch 443/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0516 - dice_coef: 0.9718Epoch 00442: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0500 - dice_coef: 0.9719 - val_loss: 0.1314 - val_dice_coef: 0.9166
# Epoch 444/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0410 - dice_coef: 0.9766Epoch 00443: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0435 - dice_coef: 0.9763 - val_loss: 0.0796 - val_dice_coef: 0.9403
# Epoch 445/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0380 - dice_coef: 0.9752Epoch 00444: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0363 - dice_coef: 0.9762 - val_loss: 0.0750 - val_dice_coef: 0.9533
# Epoch 446/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0354 - dice_coef: 0.9818Epoch 00445: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0335 - dice_coef: 0.9825 - val_loss: 0.0604 - val_dice_coef: 0.9718
# Epoch 447/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0346 - dice_coef: 0.9819Epoch 00446: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0339 - dice_coef: 0.9818 - val_loss: 0.0797 - val_dice_coef: 0.9495
# Epoch 448/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0319 - dice_coef: 0.9804Epoch 00447: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0330 - dice_coef: 0.9798 - val_loss: 0.0712 - val_dice_coef: 0.9603
# Epoch 449/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0303 - dice_coef: 0.9833Epoch 00448: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0316 - dice_coef: 0.9832 - val_loss: 0.0571 - val_dice_coef: 0.9691
# Epoch 450/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0340 - dice_coef: 0.9801Epoch 00449: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0324 - dice_coef: 0.9806 - val_loss: 0.0697 - val_dice_coef: 0.9582
# Epoch 451/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0307 - dice_coef: 0.9825Epoch 00450: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0304 - dice_coef: 0.9823 - val_loss: 0.0868 - val_dice_coef: 0.9513
# Epoch 452/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0312 - dice_coef: 0.9829Epoch 00451: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0295 - dice_coef: 0.9837 - val_loss: 0.0812 - val_dice_coef: 0.9540
# Epoch 453/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0280 - dice_coef: 0.9834Epoch 00452: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0264 - dice_coef: 0.9844 - val_loss: 0.0652 - val_dice_coef: 0.9596
# Epoch 454/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0278 - dice_coef: 0.9833Epoch 00453: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0269 - dice_coef: 0.9839 - val_loss: 0.0544 - val_dice_coef: 0.9668
# Epoch 455/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0271 - dice_coef: 0.9848Epoch 00454: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0283 - dice_coef: 0.9840 - val_loss: 0.0592 - val_dice_coef: 0.9619
# Epoch 456/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0283 - dice_coef: 0.9839Epoch 00455: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0281 - dice_coef: 0.9834 - val_loss: 0.0875 - val_dice_coef: 0.9404
# Epoch 457/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0266 - dice_coef: 0.9839Epoch 00456: val_loss improved from 0.04419 to 0.04382, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0264 - dice_coef: 0.9847 - val_loss: 0.0438 - val_dice_coef: 0.9747
# Epoch 458/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0291 - dice_coef: 0.9837Epoch 00457: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0283 - dice_coef: 0.9837 - val_loss: 0.0485 - val_dice_coef: 0.9681
# Epoch 459/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0285 - dice_coef: 0.9839Epoch 00458: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0272 - dice_coef: 0.9842 - val_loss: 0.0804 - val_dice_coef: 0.9471
# Epoch 460/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0270 - dice_coef: 0.9843Epoch 00459: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0260 - dice_coef: 0.9846 - val_loss: 0.0511 - val_dice_coef: 0.9695
# Epoch 461/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0258 - dice_coef: 0.9853Epoch 00460: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0258 - dice_coef: 0.9855 - val_loss: 0.0589 - val_dice_coef: 0.9634
# Epoch 462/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0251 - dice_coef: 0.9853Epoch 00461: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0237 - dice_coef: 0.9860 - val_loss: 0.0658 - val_dice_coef: 0.9564
# Epoch 463/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0255 - dice_coef: 0.9847Epoch 00462: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0274 - dice_coef: 0.9837 - val_loss: 0.0679 - val_dice_coef: 0.9583
# Epoch 464/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0340 - dice_coef: 0.9822Epoch 00463: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0332 - dice_coef: 0.9822 - val_loss: 0.0884 - val_dice_coef: 0.9459
# Epoch 465/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0298 - dice_coef: 0.9823Epoch 00464: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0294 - dice_coef: 0.9823 - val_loss: 0.1004 - val_dice_coef: 0.9363
# Epoch 466/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0321 - dice_coef: 0.9817Epoch 00465: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0316 - dice_coef: 0.9818 - val_loss: 0.0699 - val_dice_coef: 0.9541
# Epoch 467/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0280 - dice_coef: 0.9835Epoch 00466: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0273 - dice_coef: 0.9838 - val_loss: 0.0808 - val_dice_coef: 0.9473
# Epoch 468/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0307 - dice_coef: 0.9828Epoch 00467: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0296 - dice_coef: 0.9832 - val_loss: 0.0738 - val_dice_coef: 0.9510
# Epoch 469/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0274 - dice_coef: 0.9838Epoch 00468: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0266 - dice_coef: 0.9843 - val_loss: 0.0777 - val_dice_coef: 0.9498
# Epoch 470/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0259 - dice_coef: 0.9849Epoch 00469: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0268 - dice_coef: 0.9843 - val_loss: 0.0488 - val_dice_coef: 0.9690
# Epoch 471/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0260 - dice_coef: 0.9851Epoch 00470: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0251 - dice_coef: 0.9854 - val_loss: 0.0630 - val_dice_coef: 0.9577
# Epoch 472/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0263 - dice_coef: 0.9845Epoch 00471: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0249 - dice_coef: 0.9853 - val_loss: 0.0443 - val_dice_coef: 0.9724
# Epoch 473/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0254 - dice_coef: 0.9850Epoch 00472: val_loss improved from 0.04382 to 0.04327, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0252 - dice_coef: 0.9848 - val_loss: 0.0433 - val_dice_coef: 0.9723
# Epoch 474/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0241 - dice_coef: 0.9859Epoch 00473: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0257 - dice_coef: 0.9867 - val_loss: 0.0635 - val_dice_coef: 0.9577
# Epoch 475/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0279 - dice_coef: 0.9826Epoch 00474: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0279 - dice_coef: 0.9829 - val_loss: 0.0494 - val_dice_coef: 0.9734
# Epoch 476/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0272 - dice_coef: 0.9835Epoch 00475: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0256 - dice_coef: 0.9842 - val_loss: 0.0698 - val_dice_coef: 0.9509
# Epoch 477/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0253 - dice_coef: 0.9855Epoch 00476: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0241 - dice_coef: 0.9861 - val_loss: 0.0605 - val_dice_coef: 0.9622
# Epoch 478/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0247 - dice_coef: 0.9861Epoch 00477: val_loss improved from 0.04327 to 0.04042, saving model to saved_models/endo_models/weights-500Epochs-50Drop-Adam3.hdf5
# 7/7 [==============================] - 13s - loss: 0.0260 - dice_coef: 0.9858 - val_loss: 0.0404 - val_dice_coef: 0.9741
# Epoch 479/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0275 - dice_coef: 0.9839Epoch 00478: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0276 - dice_coef: 0.9833 - val_loss: 0.0758 - val_dice_coef: 0.9439
# Epoch 480/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0281 - dice_coef: 0.9832Epoch 00479: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0270 - dice_coef: 0.9839 - val_loss: 0.0435 - val_dice_coef: 0.9716
# Epoch 481/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0274 - dice_coef: 0.9847Epoch 00480: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0264 - dice_coef: 0.9855 - val_loss: 0.0480 - val_dice_coef: 0.9683
# Epoch 482/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0253 - dice_coef: 0.9846Epoch 00481: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0254 - dice_coef: 0.9844 - val_loss: 0.0501 - val_dice_coef: 0.9659
# Epoch 483/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0247 - dice_coef: 0.9854Epoch 00482: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0246 - dice_coef: 0.9854 - val_loss: 0.0489 - val_dice_coef: 0.9719
# Epoch 484/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0246 - dice_coef: 0.9859Epoch 00483: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0245 - dice_coef: 0.9857 - val_loss: 0.0494 - val_dice_coef: 0.9672
# Epoch 485/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0251 - dice_coef: 0.9844Epoch 00484: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0248 - dice_coef: 0.9844 - val_loss: 0.0431 - val_dice_coef: 0.9743
# Epoch 486/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0255 - dice_coef: 0.9865Epoch 00485: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0247 - dice_coef: 0.9866 - val_loss: 0.0576 - val_dice_coef: 0.9643
# Epoch 487/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0246 - dice_coef: 0.9863Epoch 00486: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0245 - dice_coef: 0.9865 - val_loss: 0.0497 - val_dice_coef: 0.9733
# Epoch 488/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0240 - dice_coef: 0.9848Epoch 00487: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0241 - dice_coef: 0.9848 - val_loss: 0.0507 - val_dice_coef: 0.9655
# Epoch 489/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0238 - dice_coef: 0.9860Epoch 00488: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0234 - dice_coef: 0.9863 - val_loss: 0.0515 - val_dice_coef: 0.9650
# Epoch 490/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0243 - dice_coef: 0.9861Epoch 00489: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0232 - dice_coef: 0.9865 - val_loss: 0.0462 - val_dice_coef: 0.9713
# Epoch 491/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0243 - dice_coef: 0.9864Epoch 00490: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0257 - dice_coef: 0.9853 - val_loss: 0.0614 - val_dice_coef: 0.9604
# Epoch 492/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0235 - dice_coef: 0.9862Epoch 00491: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0231 - dice_coef: 0.9863 - val_loss: 0.0630 - val_dice_coef: 0.9729
# Epoch 493/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0237 - dice_coef: 0.9859Epoch 00492: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0260 - dice_coef: 0.9850 - val_loss: 0.0624 - val_dice_coef: 0.9608
# Epoch 494/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0227 - dice_coef: 0.9857Epoch 00493: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0218 - dice_coef: 0.9865 - val_loss: 0.0538 - val_dice_coef: 0.9717
# Epoch 495/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0246 - dice_coef: 0.9857Epoch 00494: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0243 - dice_coef: 0.9857 - val_loss: 0.0554 - val_dice_coef: 0.9647
# Epoch 496/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0233 - dice_coef: 0.9866Epoch 00495: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0226 - dice_coef: 0.9868 - val_loss: 0.0539 - val_dice_coef: 0.9661
# Epoch 497/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0236 - dice_coef: 0.9857Epoch 00496: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0230 - dice_coef: 0.9860 - val_loss: 0.0415 - val_dice_coef: 0.9762
# Epoch 498/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0222 - dice_coef: 0.9872Epoch 00497: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0226 - dice_coef: 0.9874 - val_loss: 0.0505 - val_dice_coef: 0.9690
# Epoch 499/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0221 - dice_coef: 0.9862Epoch 00498: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0241 - dice_coef: 0.9851 - val_loss: 0.0565 - val_dice_coef: 0.9715
# Epoch 500/500
# 6/7 [========================>.....] - ETA: 1s - loss: 0.0417 - dice_coef: 0.9769Epoch 00499: val_loss did not improve
# 7/7 [==============================] - 12s - loss: 0.0416 - dice_coef: 0.9762 - val_loss: 0.0748 - val_dice_coef: 0.9486

# %%
show_plots(hist)

# %%
import tensorflow as tf

model.load_weights(weight_file)

def calculate_dice(images, masks_true):
    dices = []
    masks_pred = np.concatenate([model.predict(image[None,:,:,:]) for image in images])
    for mask_true, mask_pred in zip(masks_true, masks_pred):
        y_true = mask_true.astype('float64')
        y_pred = mask_pred.astype('float64')
        dices.append(dice_coef_np(y_true.flatten(), y_pred.flatten()))
    print("Dice Average: {:.2f} Dice Stdev: {:.2f}".format(np.mean(dices), np.std(dices)))

# %%
print("Training Statistics(No Dropout)...")
calculate_dice(train_images, train_inner_masks)
print("Validation Statistics(No Dropout)...")
calculate_dice(validation_images, validation_inner_masks)
# Out:
# Training Statistics(No Dropout)...
# Dice Average: 0.97 Dice Stdev: 0.02
# Validation Statistics(No Dropout)...
# Dice Average: 0.97 Dice Stdev: 0.01

# %% [markdown]
# # View Predictions on Validation Set

# %%
def show_masks(images, i_masks_true):
    masks_pred = np.concatenate([model.predict(image[None,:,:,:]) for image in images])
    counter = 0
    for (image,i_mask,mask_pred) in zip(images,i_masks_true,masks_pred):
        plt.figure(figsize=(10,5))
        plt.subplot(1, 3, 1)
        plt.axis("off")
        plt.imshow(i_mask, cmap=plt.cm.gray)
        plt.subplot(1,3,2)
        plt.axis("off")
        plt.imshow(np.where(mask_pred[:,:,1]>0.5,255,0),cmap=plt.cm.gray)
        plt.subplot(1, 3, 3)
        plt.axis("off")
        plt.imshow(image[:,:,0], cmap=plt.cm.gray)
        counter += 1
        filename = "{:2d}.png".format(counter)
        plt.savefig(os.path.join(save_imgs_dir, filename))
        
show_masks(images[split_index:], inner_masks[split_index:])
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
